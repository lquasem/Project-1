# %% [markdown]
# # Yelp API Restaurant Calls By Zip
#
# - Objective: Determine total count of search results of restaurants for each zip
# - Purpose: Estimate total number of unique restaurants in the Bay Area
# - Result: Stores zip codes and results counts for each in total_count_zip.csv

# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import csv

# Import API key
from api_keys import api_key

# %% [markdown]
# ### Perform API calls
#
# - Dataframe from cities_by_zip.csv
# - Build function that calls and writes restaurant data to new csv, given a zip
# - Run list of zips through function

# %%
# Create dataframe from csv file
zip_df = pd.read_csv("Resources/cities_by_zip.csv", names=["Zip", "City", "County"])
zip_df
# Out:
#        Zip           City   County
# 0    94501       Alameda   Alameda
# 1    94502       Alameda   Alameda
# 2    94706        Albany   Alameda
# 3    94707        Albany   Alameda
# 4    94710        Albany   Alameda
# 5    94701      Berkeley   Alameda
# 6    94702      Berkeley   Alameda
# 7    94703      Berkeley   Alameda
# 8    94704      Berkeley   Alameda
# 9    94705      Berkeley   Alameda
# 10   94706      Berkeley   Alameda
# 11   94707      Berkeley   Alameda
# 12   94708      Berkeley   Alameda
# 13   94709      Berkeley   Alameda
# 14   94710      Berkeley   Alameda
# 15   94712      Berkeley   Alameda
# 16   94720      Berkeley   Alameda
# 17   94568        Dublin   Alameda
# 18   94608    Emeryville   Alameda
# 19   94662    Emeryville   Alameda
# 20   94536       Fremont   Alameda
# 21   94537       Fremont   Alameda
# 22   94538       Fremont   Alameda
# 23   94539       Fremont   Alameda
# 24   94555       Fremont   Alameda
# 25   94540       Hayward   Alameda
# 26   94541       Hayward   Alameda
# 27   94542       Hayward   Alameda
# 28   94543       Hayward   Alameda
# 29   94544       Hayward   Alameda
# ..     ...            ...      ...
# 365  94590       Vallejo    Solano
# 366  94591       Vallejo    Solano
# 367  94592       Vallejo    Solano
# 368  95425    Cloverdale    Sonoma
# 369  94926        Cotati    Sonoma
# 370  94927        Cotati    Sonoma
# 371  94928        Cotati    Sonoma
# 372  94931        Cotati    Sonoma
# 373  95448    Healdsburg    Sonoma
# 374  94952      Petaluma    Sonoma
# 375  94953      Petaluma    Sonoma
# 376  94954      Petaluma    Sonoma
# 377  94955      Petaluma    Sonoma
# 378  94975      Petaluma    Sonoma
# 379  94999      Petaluma    Sonoma
# 380  94926  Rohnert Park    Sonoma
# 381  94927  Rohnert Park    Sonoma
# 382  94928  Rohnert Park    Sonoma
# 383  95401    Santa Rosa    Sonoma
# 384  95402    Santa Rosa    Sonoma
# 385  95403    Santa Rosa    Sonoma
# 386  95404    Santa Rosa    Sonoma
# 387  95405    Santa Rosa    Sonoma
# 388  95406    Santa Rosa    Sonoma
# 389  95407    Santa Rosa    Sonoma
# 390  95409    Santa Rosa    Sonoma
# 391  95472    Sebastopol    Sonoma
# 392  95473    Sebastopol    Sonoma
# 393  95476        Sonoma    Sonoma
# 394  95492       Windsor    Sonoma
#
# [395 rows x 3 columns]

# %%
# Function returns 50 restaurant listings for input zip.
# Unlike other API call functions in repo, this is seeking total counts in the area instead of restaurant data
def get_restaurants(zipcode, api_key):
    
    url = "https://api.yelp.com/v3/businesses/search"
    headers = {"Authorization": "Bearer %s" % api_key}
    restaurant_data = []
    count = 0

    # Set parameters and pass into API calls
    params = {"term": "restaurants", "location":zipcode, "limit":50}
    req = requests.get(url, params=params, headers=headers)

    # Breaks if error occurs with search
    if req.status_code == 400:
        count+=1
        print(f"Error for coordinate {count}")
    elif req.status_code == 200:

        # Convert to json
        response = req.json()

        # Log history
        count += 1
        print(f"Now processing query {zipcode}")

        # Iterate through business results and extract data
        for biz in response["businesses"]:

            # Logic to replace missing price level data with NaN
            if "price" not in biz:
                # If also missing category data, replace entry with NaN
                if biz["categories"] == []:
                    restaurant_data.append([zipcode, biz["name"], biz["coordinates"]["latitude"], 
                                        biz["coordinates"]["longitude"], biz["location"]["address1"], 
                                        biz["location"]["zip_code"], biz["rating"], 
                                        biz["review_count"], "", "", biz["id"]])
                else:
                    restaurant_data.append([zipcode, biz["name"], biz["coordinates"]["latitude"], 
                                            biz["coordinates"]["longitude"], biz["location"]["address1"], 
                                            biz["location"]["zip_code"], biz["rating"], 
                                            biz["review_count"], "", biz["categories"][0]["title"], 
                                            biz["id"]])

            # Replace missing category data with empty string
            elif biz["categories"] == []:
                restaurant_data.append([zipcode, biz["name"], biz["coordinates"]["latitude"], 
                                        biz["coordinates"]["longitude"], biz["location"]["address1"], 
                                        biz["location"]["zip_code"], biz["rating"], 
                                        biz["review_count"], biz["price"], "", biz["id"]])

            else:
                restaurant_data.append([zipcode, biz["name"], biz["coordinates"]["latitude"], 
                                        biz["coordinates"]["longitude"], biz["location"]["address1"], 
                                        biz["location"]["zip_code"], biz["rating"], 
                                        biz["review_count"], biz["price"], 
                                        biz["categories"][0]["title"], biz["id"]])

    # Write to csv
    with open('Resources/zipcode_datatotestreliability.csv', 'a', encoding="utf-8") as csvFile:
        writer = csv.writer(csvFile)
        writer.writerows(restaurant_data)
    csvFile.close()
    
    # Returns total count of restaurants in zip
    return response["total"]

# %%
# Track # of zips processed
count = 0

# List to track total restaurants found in zip
totals_count = []

print("LOG HISTORY OF API CALLS:")
print("---------------------------")

# Loop thru list of zips in zip_df
for zipcode in zip_df["Zip"]:
    
    #  Call get_restaurants fn and append to total_count list
    totals_count.append(get_restaurants(zipcode, api_key))
    
    # Print log history
    count += 1
    rem = len(zip_df["Zip"]) - count
    print("-----------------------------------------")
    if zipcode == zip_df.iloc[-1,0]:
        print("Full list of zip codes processed!")
    elif zipcode == zip_df.iloc[-2,0]:
        print("Now getting results for final zip code. Almost there!")
        print("-----------------------------------------")
    else:
        print(f"Data retrieval for {zipcode} complete")
        print(f"Getting results for next zip code.. there are {rem} zips left")
        print("-----------------------------------------")

zip_df["Total # of Restaurants"] = totals_count
# Out:
# LOG HISTORY OF API CALLS:
# ---------------------------
# Now processing query set 1 of max 20 for 94501
# -----------------------------------------
# Data retrieval for 94501 complete
# Getting results for next zip code.. there are 394 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94502
# -----------------------------------------
# Data retrieval for 94502 complete
# Getting results for next zip code.. there are 393 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94706
# -----------------------------------------
# Data retrieval for 94706 complete
# Getting results for next zip code.. there are 392 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94707
# -----------------------------------------
# Data retrieval for 94707 complete
# Getting results for next zip code.. there are 391 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94710
# -----------------------------------------
# Data retrieval for 94710 complete
# Getting results for next zip code.. there are 390 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94701
# -----------------------------------------
# Data retrieval for 94701 complete
# Getting results for next zip code.. there are 389 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94702
# -----------------------------------------
# Data retrieval for 94702 complete
# Getting results for next zip code.. there are 388 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94703
# -----------------------------------------
# Data retrieval for 94703 complete
# Getting results for next zip code.. there are 387 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94704
# -----------------------------------------
# Data retrieval for 94704 complete
# Getting results for next zip code.. there are 386 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94705
# -----------------------------------------
# Data retrieval for 94705 complete
# Getting results for next zip code.. there are 385 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94706
# -----------------------------------------
# Data retrieval for 94706 complete
# Getting results for next zip code.. there are 384 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94707
# -----------------------------------------
# Data retrieval for 94707 complete
# Getting results for next zip code.. there are 383 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94708
# -----------------------------------------
# Data retrieval for 94708 complete
# Getting results for next zip code.. there are 382 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94709
# -----------------------------------------
# Data retrieval for 94709 complete
# Getting results for next zip code.. there are 381 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94710
# -----------------------------------------
# Data retrieval for 94710 complete
# Getting results for next zip code.. there are 380 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94712
# -----------------------------------------
# Data retrieval for 94712 complete
# Getting results for next zip code.. there are 379 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94720
# -----------------------------------------
# Data retrieval for 94720 complete
# Getting results for next zip code.. there are 378 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94568
# -----------------------------------------
# Data retrieval for 94568 complete
# Getting results for next zip code.. there are 377 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94608
# -----------------------------------------
# Data retrieval for 94608 complete
# Getting results for next zip code.. there are 376 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94662
# -----------------------------------------
# Data retrieval for 94662 complete
# Getting results for next zip code.. there are 375 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94536
# -----------------------------------------
# Data retrieval for 94536 complete
# Getting results for next zip code.. there are 374 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94537
# -----------------------------------------
# Data retrieval for 94537 complete
# Getting results for next zip code.. there are 373 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94538
# -----------------------------------------
# Data retrieval for 94538 complete
# Getting results for next zip code.. there are 372 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94539
# -----------------------------------------
# Data retrieval for 94539 complete
# Getting results for next zip code.. there are 371 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94555
# -----------------------------------------
# Data retrieval for 94555 complete
# Getting results for next zip code.. there are 370 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94540
# -----------------------------------------
# Data retrieval for 94540 complete
# Getting results for next zip code.. there are 369 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94541
# -----------------------------------------
# Data retrieval for 94541 complete
# Getting results for next zip code.. there are 368 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94542
# -----------------------------------------
# Data retrieval for 94542 complete
# Getting results for next zip code.. there are 367 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94543
# -----------------------------------------
# Data retrieval for 94543 complete
# Getting results for next zip code.. there are 366 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94544
# -----------------------------------------
# Data retrieval for 94544 complete
# Getting results for next zip code.. there are 365 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94545
# -----------------------------------------
# Data retrieval for 94545 complete
# Getting results for next zip code.. there are 364 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94546
# -----------------------------------------
# Data retrieval for 94546 complete
# Getting results for next zip code.. there are 363 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94552
# -----------------------------------------
# Data retrieval for 94552 complete
# Getting results for next zip code.. there are 362 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94557
# -----------------------------------------
# Data retrieval for 94557 complete
# Getting results for next zip code.. there are 361 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94550
# -----------------------------------------
# Data retrieval for 94550 complete
# Getting results for next zip code.. there are 360 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94551
# -----------------------------------------
# Data retrieval for 94551 complete
# Getting results for next zip code.. there are 359 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94560
# -----------------------------------------
# Data retrieval for 94560 complete
# Getting results for next zip code.. there are 358 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94601
# -----------------------------------------
# Data retrieval for 94601 complete
# Getting results for next zip code.. there are 357 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94602
# -----------------------------------------
# Data retrieval for 94602 complete
# Getting results for next zip code.. there are 356 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94603
# -----------------------------------------
# Data retrieval for 94603 complete
# Getting results for next zip code.. there are 355 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94604
# -----------------------------------------
# Data retrieval for 94604 complete
# Getting results for next zip code.. there are 354 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94605
# -----------------------------------------
# Data retrieval for 94605 complete
# Getting results for next zip code.. there are 353 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94606
# -----------------------------------------
# Data retrieval for 94606 complete
# Getting results for next zip code.. there are 352 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94607
# -----------------------------------------
# Data retrieval for 94607 complete
# Getting results for next zip code.. there are 351 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94608
# -----------------------------------------
# Data retrieval for 94608 complete
# Getting results for next zip code.. there are 350 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94609
# -----------------------------------------
# Data retrieval for 94609 complete
# Getting results for next zip code.. there are 349 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94610
# -----------------------------------------
# Data retrieval for 94610 complete
# Getting results for next zip code.. there are 348 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94611
# -----------------------------------------
# Data retrieval for 94611 complete
# Getting results for next zip code.. there are 347 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94612
# -----------------------------------------
# Data retrieval for 94612 complete
# Getting results for next zip code.. there are 346 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94613
# -----------------------------------------
# Data retrieval for 94613 complete
# Getting results for next zip code.. there are 345 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94614
# -----------------------------------------
# Data retrieval for 94614 complete
# Getting results for next zip code.. there are 344 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94615
# -----------------------------------------
# Data retrieval for 94615 complete
# Getting results for next zip code.. there are 343 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94616
# -----------------------------------------
# Data retrieval for 94616 complete
# Getting results for next zip code.. there are 342 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94617
# -----------------------------------------
# Data retrieval for 94617 complete
# Getting results for next zip code.. there are 341 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94618
# -----------------------------------------
# Data retrieval for 94618 complete
# Getting results for next zip code.. there are 340 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94619
# -----------------------------------------
# Data retrieval for 94619 complete
# Getting results for next zip code.. there are 339 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94620
# -----------------------------------------
# Data retrieval for 94620 complete
# Getting results for next zip code.. there are 338 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94621
# -----------------------------------------
# Data retrieval for 94621 complete
# Getting results for next zip code.. there are 337 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94622
# -----------------------------------------
# Data retrieval for 94622 complete
# Getting results for next zip code.. there are 336 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94623
# -----------------------------------------
# Data retrieval for 94623 complete
# Getting results for next zip code.. there are 335 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94624
# -----------------------------------------
# Data retrieval for 94624 complete
# Getting results for next zip code.. there are 334 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94649
# -----------------------------------------
# Data retrieval for 94649 complete
# Getting results for next zip code.. there are 333 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94659
# -----------------------------------------
# Data retrieval for 94659 complete
# Getting results for next zip code.. there are 332 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94660
# -----------------------------------------
# Data retrieval for 94660 complete
# Getting results for next zip code.. there are 331 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94661
# -----------------------------------------
# Data retrieval for 94661 complete
# Getting results for next zip code.. there are 330 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94666
# -----------------------------------------
# Data retrieval for 94666 complete
# Getting results for next zip code.. there are 329 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94602
# -----------------------------------------
# Data retrieval for 94602 complete
# Getting results for next zip code.. there are 328 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94610
# -----------------------------------------
# Data retrieval for 94610 complete
# Getting results for next zip code.. there are 327 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94611
# -----------------------------------------
# Data retrieval for 94611 complete
# Getting results for next zip code.. there are 326 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94618
# -----------------------------------------
# Data retrieval for 94618 complete
# Getting results for next zip code.. there are 325 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94620
# -----------------------------------------
# Data retrieval for 94620 complete
# Getting results for next zip code.. there are 324 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94566
# -----------------------------------------
# Data retrieval for 94566 complete
# Getting results for next zip code.. there are 323 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94568
# -----------------------------------------
# Data retrieval for 94568 complete
# Getting results for next zip code.. there are 322 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94588
# -----------------------------------------
# Data retrieval for 94588 complete
# Getting results for next zip code.. there are 321 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94577
# -----------------------------------------
# Data retrieval for 94577 complete
# Getting results for next zip code.. there are 320 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94578
# -----------------------------------------
# Data retrieval for 94578 complete
# Getting results for next zip code.. there are 319 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94579
# -----------------------------------------
# Data retrieval for 94579 complete
# Getting results for next zip code.. there are 318 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94587
# -----------------------------------------
# Data retrieval for 94587 complete
# Getting results for next zip code.. there are 317 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94509
# -----------------------------------------
# Data retrieval for 94509 complete
# Getting results for next zip code.. there are 316 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94531
# -----------------------------------------
# Data retrieval for 94531 complete
# Getting results for next zip code.. there are 315 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94513
# -----------------------------------------
# Data retrieval for 94513 complete
# Getting results for next zip code.. there are 314 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94517
# -----------------------------------------
# Data retrieval for 94517 complete
# Getting results for next zip code.. there are 313 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94518
# -----------------------------------------
# Data retrieval for 94518 complete
# Getting results for next zip code.. there are 312 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94519
# -----------------------------------------
# Data retrieval for 94519 complete
# Getting results for next zip code.. there are 311 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94520
# -----------------------------------------
# Data retrieval for 94520 complete
# Getting results for next zip code.. there are 310 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94521
# -----------------------------------------
# Data retrieval for 94521 complete
# Getting results for next zip code.. there are 309 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94522
# -----------------------------------------
# Data retrieval for 94522 complete
# Getting results for next zip code.. there are 308 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94523
# -----------------------------------------
# Data retrieval for 94523 complete
# Getting results for next zip code.. there are 307 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94524
# -----------------------------------------
# Data retrieval for 94524 complete
# Getting results for next zip code.. there are 306 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94527
# -----------------------------------------
# Data retrieval for 94527 complete
# Getting results for next zip code.. there are 305 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94529
# -----------------------------------------
# Data retrieval for 94529 complete
# Getting results for next zip code.. there are 304 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94506
# -----------------------------------------
# Data retrieval for 94506 complete
# Getting results for next zip code.. there are 303 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94526
# -----------------------------------------
# Data retrieval for 94526 complete
# Getting results for next zip code.. there are 302 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94530
# -----------------------------------------
# Data retrieval for 94530 complete
# Getting results for next zip code.. there are 301 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94547
# -----------------------------------------
# Data retrieval for 94547 complete
# Getting results for next zip code.. there are 300 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94549
# -----------------------------------------
# Data retrieval for 94549 complete
# Getting results for next zip code.. there are 299 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94553
# -----------------------------------------
# Data retrieval for 94553 complete
# Getting results for next zip code.. there are 298 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94556
# -----------------------------------------
# Data retrieval for 94556 complete
# Getting results for next zip code.. there are 297 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94570
# -----------------------------------------
# Data retrieval for 94570 complete
# Getting results for next zip code.. there are 296 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94575
# -----------------------------------------
# Data retrieval for 94575 complete
# Getting results for next zip code.. there are 295 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94561
# -----------------------------------------
# Data retrieval for 94561 complete
# Getting results for next zip code.. there are 294 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94563
# -----------------------------------------
# Data retrieval for 94563 complete
# Getting results for next zip code.. there are 293 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94564
# -----------------------------------------
# Data retrieval for 94564 complete
# Getting results for next zip code.. there are 292 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94565
# -----------------------------------------
# Data retrieval for 94565 complete
# Getting results for next zip code.. there are 291 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94523
# -----------------------------------------
# Data retrieval for 94523 complete
# Getting results for next zip code.. there are 290 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94801
# -----------------------------------------
# Data retrieval for 94801 complete
# Getting results for next zip code.. there are 289 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94802
# -----------------------------------------
# Data retrieval for 94802 complete
# Getting results for next zip code.. there are 288 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94803
# -----------------------------------------
# Data retrieval for 94803 complete
# Getting results for next zip code.. there are 287 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94804
# -----------------------------------------
# Data retrieval for 94804 complete
# Getting results for next zip code.. there are 286 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94805
# -----------------------------------------
# Data retrieval for 94805 complete
# Getting results for next zip code.. there are 285 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94806
# -----------------------------------------
# Data retrieval for 94806 complete
# Getting results for next zip code.. there are 284 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94807
# -----------------------------------------
# Data retrieval for 94807 complete
# Getting results for next zip code.. there are 283 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94808
# -----------------------------------------
# Data retrieval for 94808 complete
# Getting results for next zip code.. there are 282 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94820
# -----------------------------------------
# Data retrieval for 94820 complete
# Getting results for next zip code.. there are 281 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94850
# -----------------------------------------
# Data retrieval for 94850 complete
# Getting results for next zip code.. there are 280 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94803
# -----------------------------------------
# Data retrieval for 94803 complete
# Getting results for next zip code.. there are 279 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94805
# -----------------------------------------
# Data retrieval for 94805 complete
# Getting results for next zip code.. there are 278 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94806
# -----------------------------------------
# Data retrieval for 94806 complete
# Getting results for next zip code.. there are 277 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94582
# -----------------------------------------
# Data retrieval for 94582 complete
# Getting results for next zip code.. there are 276 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94583
# -----------------------------------------
# Data retrieval for 94583 complete
# Getting results for next zip code.. there are 275 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94595
# -----------------------------------------
# Data retrieval for 94595 complete
# Getting results for next zip code.. there are 274 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94596
# -----------------------------------------
# Data retrieval for 94596 complete
# Getting results for next zip code.. there are 273 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94597
# -----------------------------------------
# Data retrieval for 94597 complete
# Getting results for next zip code.. there are 272 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94598
# -----------------------------------------
# Data retrieval for 94598 complete
# Getting results for next zip code.. there are 271 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94920
# -----------------------------------------
# Data retrieval for 94920 complete
# Getting results for next zip code.. there are 270 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94925
# -----------------------------------------
# Data retrieval for 94925 complete
# Getting results for next zip code.. there are 269 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94976
# -----------------------------------------
# Data retrieval for 94976 complete
# Getting results for next zip code.. there are 268 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94978
# -----------------------------------------
# Data retrieval for 94978 complete
# Getting results for next zip code.. there are 267 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94930
# -----------------------------------------
# Data retrieval for 94930 complete
# Getting results for next zip code.. there are 266 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94939
# -----------------------------------------
# Data retrieval for 94939 complete
# Getting results for next zip code.. there are 265 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94977
# -----------------------------------------
# Data retrieval for 94977 complete
# Getting results for next zip code.. there are 264 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94941
# -----------------------------------------
# Data retrieval for 94941 complete
# Getting results for next zip code.. there are 263 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94942
# -----------------------------------------
# Data retrieval for 94942 complete
# Getting results for next zip code.. there are 262 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94945
# -----------------------------------------
# Data retrieval for 94945 complete
# Getting results for next zip code.. there are 261 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94947
# -----------------------------------------
# Data retrieval for 94947 complete
# Getting results for next zip code.. there are 260 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94948
# -----------------------------------------
# Data retrieval for 94948 complete
# Getting results for next zip code.. there are 259 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94949
# -----------------------------------------
# Data retrieval for 94949 complete
# Getting results for next zip code.. there are 258 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94998
# -----------------------------------------
# Data retrieval for 94998 complete
# Getting results for next zip code.. there are 257 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94957
# -----------------------------------------
# Data retrieval for 94957 complete
# Getting results for next zip code.. there are 256 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94901
# -----------------------------------------
# Data retrieval for 94901 complete
# Getting results for next zip code.. there are 255 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94960
# -----------------------------------------
# Data retrieval for 94960 complete
# Getting results for next zip code.. there are 254 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94979
# -----------------------------------------
# Data retrieval for 94979 complete
# Getting results for next zip code.. there are 253 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94901
# -----------------------------------------
# Data retrieval for 94901 complete
# Getting results for next zip code.. there are 252 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94903
# -----------------------------------------
# Data retrieval for 94903 complete
# Getting results for next zip code.. there are 251 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94912
# -----------------------------------------
# Data retrieval for 94912 complete
# Getting results for next zip code.. there are 250 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94913
# -----------------------------------------
# Data retrieval for 94913 complete
# Getting results for next zip code.. there are 249 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94915
# -----------------------------------------
# Data retrieval for 94915 complete
# Getting results for next zip code.. there are 248 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94965
# -----------------------------------------
# Data retrieval for 94965 complete
# Getting results for next zip code.. there are 247 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94966
# -----------------------------------------
# Data retrieval for 94966 complete
# Getting results for next zip code.. there are 246 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94920
# -----------------------------------------
# Data retrieval for 94920 complete
# Getting results for next zip code.. there are 245 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94503
# -----------------------------------------
# Data retrieval for 94503 complete
# Getting results for next zip code.. there are 244 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94589
# -----------------------------------------
# Data retrieval for 94589 complete
# Getting results for next zip code.. there are 243 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94515
# -----------------------------------------
# Data retrieval for 94515 complete
# Getting results for next zip code.. there are 242 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94558
# -----------------------------------------
# Data retrieval for 94558 complete
# Getting results for next zip code.. there are 241 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94559
# -----------------------------------------
# Data retrieval for 94559 complete
# Getting results for next zip code.. there are 240 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94581
# -----------------------------------------
# Data retrieval for 94581 complete
# Getting results for next zip code.. there are 239 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94574
# -----------------------------------------
# Data retrieval for 94574 complete
# Getting results for next zip code.. there are 238 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94599
# -----------------------------------------
# Data retrieval for 94599 complete
# Getting results for next zip code.. there are 237 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94102
# -----------------------------------------
# Data retrieval for 94102 complete
# Getting results for next zip code.. there are 236 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94103
# -----------------------------------------
# Data retrieval for 94103 complete
# Getting results for next zip code.. there are 235 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94104
# -----------------------------------------
# Data retrieval for 94104 complete
# Getting results for next zip code.. there are 234 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94105
# -----------------------------------------
# Data retrieval for 94105 complete
# Getting results for next zip code.. there are 233 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94107
# -----------------------------------------
# Data retrieval for 94107 complete
# Getting results for next zip code.. there are 232 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94108
# -----------------------------------------
# Data retrieval for 94108 complete
# Getting results for next zip code.. there are 231 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94109
# -----------------------------------------
# Data retrieval for 94109 complete
# Getting results for next zip code.. there are 230 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94110
# -----------------------------------------
# Data retrieval for 94110 complete
# Getting results for next zip code.. there are 229 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94111
# -----------------------------------------
# Data retrieval for 94111 complete
# Getting results for next zip code.. there are 228 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94112
# -----------------------------------------
# Data retrieval for 94112 complete
# Getting results for next zip code.. there are 227 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94114
# -----------------------------------------
# Data retrieval for 94114 complete
# Getting results for next zip code.. there are 226 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94115
# -----------------------------------------
# Data retrieval for 94115 complete
# Getting results for next zip code.. there are 225 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94116
# -----------------------------------------
# Data retrieval for 94116 complete
# Getting results for next zip code.. there are 224 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94117
# -----------------------------------------
# Data retrieval for 94117 complete
# Getting results for next zip code.. there are 223 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94118
# -----------------------------------------
# Data retrieval for 94118 complete
# Getting results for next zip code.. there are 222 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94119
# -----------------------------------------
# Data retrieval for 94119 complete
# Getting results for next zip code.. there are 221 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94120
# -----------------------------------------
# Data retrieval for 94120 complete
# Getting results for next zip code.. there are 220 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94121
# -----------------------------------------
# Data retrieval for 94121 complete
# Getting results for next zip code.. there are 219 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94122
# -----------------------------------------
# Data retrieval for 94122 complete
# Getting results for next zip code.. there are 218 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94123
# -----------------------------------------
# Data retrieval for 94123 complete
# Getting results for next zip code.. there are 217 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94124
# -----------------------------------------
# Data retrieval for 94124 complete
# Getting results for next zip code.. there are 216 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94125
# -----------------------------------------
# Data retrieval for 94125 complete
# Getting results for next zip code.. there are 215 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94126
# -----------------------------------------
# Data retrieval for 94126 complete
# Getting results for next zip code.. there are 214 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94127
# -----------------------------------------
# Data retrieval for 94127 complete
# Getting results for next zip code.. there are 213 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94128
# -----------------------------------------
# Data retrieval for 94128 complete
# Getting results for next zip code.. there are 212 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94129
# -----------------------------------------
# Data retrieval for 94129 complete
# Getting results for next zip code.. there are 211 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94130
# -----------------------------------------
# Data retrieval for 94130 complete
# Getting results for next zip code.. there are 210 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94131
# -----------------------------------------
# Data retrieval for 94131 complete
# Getting results for next zip code.. there are 209 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94132
# -----------------------------------------
# Data retrieval for 94132 complete
# Getting results for next zip code.. there are 208 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94133
# -----------------------------------------
# Data retrieval for 94133 complete
# Getting results for next zip code.. there are 207 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94134
# -----------------------------------------
# Data retrieval for 94134 complete
# Getting results for next zip code.. there are 206 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94137
# -----------------------------------------
# Data retrieval for 94137 complete
# Getting results for next zip code.. there are 205 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94139
# -----------------------------------------
# Data retrieval for 94139 complete
# Getting results for next zip code.. there are 204 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94140
# -----------------------------------------
# Data retrieval for 94140 complete
# Getting results for next zip code.. there are 203 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94141
# -----------------------------------------
# Data retrieval for 94141 complete
# Getting results for next zip code.. there are 202 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94142
# -----------------------------------------
# Data retrieval for 94142 complete
# Getting results for next zip code.. there are 201 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94143
# -----------------------------------------
# Data retrieval for 94143 complete
# Getting results for next zip code.. there are 200 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94144
# -----------------------------------------
# Data retrieval for 94144 complete
# Getting results for next zip code.. there are 199 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94145
# -----------------------------------------
# Data retrieval for 94145 complete
# Getting results for next zip code.. there are 198 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94146
# -----------------------------------------
# Data retrieval for 94146 complete
# Getting results for next zip code.. there are 197 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94147
# -----------------------------------------
# Data retrieval for 94147 complete
# Getting results for next zip code.. there are 196 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94151
# -----------------------------------------
# Data retrieval for 94151 complete
# Getting results for next zip code.. there are 195 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94158
# -----------------------------------------
# Data retrieval for 94158 complete
# Getting results for next zip code.. there are 194 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94159
# -----------------------------------------
# Data retrieval for 94159 complete
# Getting results for next zip code.. there are 193 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94160
# -----------------------------------------
# Data retrieval for 94160 complete
# Getting results for next zip code.. there are 192 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94161
# -----------------------------------------
# Data retrieval for 94161 complete
# Getting results for next zip code.. there are 191 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94163
# -----------------------------------------
# Data retrieval for 94163 complete
# Getting results for next zip code.. there are 190 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94164
# -----------------------------------------
# Data retrieval for 94164 complete
# Getting results for next zip code.. there are 189 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94172
# -----------------------------------------
# Data retrieval for 94172 complete
# Getting results for next zip code.. there are 188 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94177
# -----------------------------------------
# Data retrieval for 94177 complete
# Getting results for next zip code.. there are 187 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94188
# -----------------------------------------
# Data retrieval for 94188 complete
# Getting results for next zip code.. there are 186 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94027
# -----------------------------------------
# Data retrieval for 94027 complete
# Getting results for next zip code.. there are 185 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94002
# -----------------------------------------
# Data retrieval for 94002 complete
# Getting results for next zip code.. there are 184 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94005
# -----------------------------------------
# Data retrieval for 94005 complete
# Getting results for next zip code.. there are 183 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94010
# -----------------------------------------
# Data retrieval for 94010 complete
# Getting results for next zip code.. there are 182 zips left
# -----------------------------------------
# ...
# Now processing query set 1 of max 20 for 95156
# -----------------------------------------
# Data retrieval for 95156 complete
# Getting results for next zip code.. there are 71 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95157
# -----------------------------------------
# Data retrieval for 95157 complete
# Getting results for next zip code.. there are 70 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95158
# -----------------------------------------
# Data retrieval for 95158 complete
# Getting results for next zip code.. there are 69 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95159
# -----------------------------------------
# Data retrieval for 95159 complete
# Getting results for next zip code.. there are 68 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95160
# -----------------------------------------
# Data retrieval for 95160 complete
# Getting results for next zip code.. there are 67 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95161
# -----------------------------------------
# Data retrieval for 95161 complete
# Getting results for next zip code.. there are 66 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95164
# -----------------------------------------
# Data retrieval for 95164 complete
# Getting results for next zip code.. there are 65 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95170
# -----------------------------------------
# Data retrieval for 95170 complete
# Getting results for next zip code.. there are 64 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95172
# -----------------------------------------
# Data retrieval for 95172 complete
# Getting results for next zip code.. there are 63 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95173
# -----------------------------------------
# Data retrieval for 95173 complete
# Getting results for next zip code.. there are 62 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95190
# -----------------------------------------
# Data retrieval for 95190 complete
# Getting results for next zip code.. there are 61 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95191
# -----------------------------------------
# Data retrieval for 95191 complete
# Getting results for next zip code.. there are 60 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95192
# -----------------------------------------
# Data retrieval for 95192 complete
# Getting results for next zip code.. there are 59 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95193
# -----------------------------------------
# Data retrieval for 95193 complete
# Getting results for next zip code.. there are 58 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95196
# -----------------------------------------
# Data retrieval for 95196 complete
# Getting results for next zip code.. there are 57 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95050
# -----------------------------------------
# Data retrieval for 95050 complete
# Getting results for next zip code.. there are 56 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95051
# -----------------------------------------
# Data retrieval for 95051 complete
# Getting results for next zip code.. there are 55 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95052
# -----------------------------------------
# Data retrieval for 95052 complete
# Getting results for next zip code.. there are 54 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95053
# -----------------------------------------
# Data retrieval for 95053 complete
# Getting results for next zip code.. there are 53 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95054
# -----------------------------------------
# Data retrieval for 95054 complete
# Getting results for next zip code.. there are 52 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95055
# -----------------------------------------
# Data retrieval for 95055 complete
# Getting results for next zip code.. there are 51 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95056
# -----------------------------------------
# Data retrieval for 95056 complete
# Getting results for next zip code.. there are 50 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95070
# -----------------------------------------
# Data retrieval for 95070 complete
# Getting results for next zip code.. there are 49 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95071
# -----------------------------------------
# Data retrieval for 95071 complete
# Getting results for next zip code.. there are 48 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94085
# -----------------------------------------
# Data retrieval for 94085 complete
# Getting results for next zip code.. there are 47 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94086
# -----------------------------------------
# Data retrieval for 94086 complete
# Getting results for next zip code.. there are 46 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94087
# -----------------------------------------
# Data retrieval for 94087 complete
# Getting results for next zip code.. there are 45 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94088
# -----------------------------------------
# Data retrieval for 94088 complete
# Getting results for next zip code.. there are 44 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94089
# -----------------------------------------
# Data retrieval for 94089 complete
# Getting results for next zip code.. there are 43 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94510
# -----------------------------------------
# Data retrieval for 94510 complete
# Getting results for next zip code.. there are 42 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95620
# -----------------------------------------
# Data retrieval for 95620 complete
# Getting results for next zip code.. there are 41 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94533
# -----------------------------------------
# Data retrieval for 94533 complete
# Getting results for next zip code.. there are 40 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94534
# -----------------------------------------
# Data retrieval for 94534 complete
# Getting results for next zip code.. there are 39 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94535
# -----------------------------------------
# Data retrieval for 94535 complete
# Getting results for next zip code.. there are 38 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94571
# -----------------------------------------
# Data retrieval for 94571 complete
# Getting results for next zip code.. there are 37 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94534
# -----------------------------------------
# Data retrieval for 94534 complete
# Getting results for next zip code.. there are 36 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94585
# -----------------------------------------
# Data retrieval for 94585 complete
# Getting results for next zip code.. there are 35 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95687
# -----------------------------------------
# Data retrieval for 95687 complete
# Getting results for next zip code.. there are 34 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95688
# -----------------------------------------
# Data retrieval for 95688 complete
# Getting results for next zip code.. there are 33 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95696
# -----------------------------------------
# Data retrieval for 95696 complete
# Getting results for next zip code.. there are 32 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94503
# -----------------------------------------
# Data retrieval for 94503 complete
# Getting results for next zip code.. there are 31 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94589
# -----------------------------------------
# Data retrieval for 94589 complete
# Getting results for next zip code.. there are 30 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94590
# -----------------------------------------
# Data retrieval for 94590 complete
# Getting results for next zip code.. there are 29 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94591
# -----------------------------------------
# Data retrieval for 94591 complete
# Getting results for next zip code.. there are 28 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94592
# -----------------------------------------
# Data retrieval for 94592 complete
# Getting results for next zip code.. there are 27 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95425
# -----------------------------------------
# Data retrieval for 95425 complete
# Getting results for next zip code.. there are 26 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94926
# -----------------------------------------
# Data retrieval for 94926 complete
# Getting results for next zip code.. there are 25 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94927
# -----------------------------------------
# Data retrieval for 94927 complete
# Getting results for next zip code.. there are 24 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94928
# -----------------------------------------
# Data retrieval for 94928 complete
# Getting results for next zip code.. there are 23 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94931
# -----------------------------------------
# Data retrieval for 94931 complete
# Getting results for next zip code.. there are 22 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95448
# -----------------------------------------
# Data retrieval for 95448 complete
# Getting results for next zip code.. there are 21 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94952
# -----------------------------------------
# Data retrieval for 94952 complete
# Getting results for next zip code.. there are 20 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94953
# -----------------------------------------
# Data retrieval for 94953 complete
# Getting results for next zip code.. there are 19 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94954
# -----------------------------------------
# Data retrieval for 94954 complete
# Getting results for next zip code.. there are 18 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94955
# -----------------------------------------
# Data retrieval for 94955 complete
# Getting results for next zip code.. there are 17 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94975
# -----------------------------------------
# Data retrieval for 94975 complete
# Getting results for next zip code.. there are 16 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94999
# -----------------------------------------
# Data retrieval for 94999 complete
# Getting results for next zip code.. there are 15 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94926
# -----------------------------------------
# Data retrieval for 94926 complete
# Getting results for next zip code.. there are 14 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94927
# -----------------------------------------
# Data retrieval for 94927 complete
# Getting results for next zip code.. there are 13 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 94928
# -----------------------------------------
# Data retrieval for 94928 complete
# Getting results for next zip code.. there are 12 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95401
# -----------------------------------------
# Data retrieval for 95401 complete
# Getting results for next zip code.. there are 11 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95402
# -----------------------------------------
# Data retrieval for 95402 complete
# Getting results for next zip code.. there are 10 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95403
# -----------------------------------------
# Data retrieval for 95403 complete
# Getting results for next zip code.. there are 9 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95404
# -----------------------------------------
# Data retrieval for 95404 complete
# Getting results for next zip code.. there are 8 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95405
# -----------------------------------------
# Data retrieval for 95405 complete
# Getting results for next zip code.. there are 7 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95406
# -----------------------------------------
# Data retrieval for 95406 complete
# Getting results for next zip code.. there are 6 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95407
# -----------------------------------------
# Data retrieval for 95407 complete
# Getting results for next zip code.. there are 5 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95409
# -----------------------------------------
# Data retrieval for 95409 complete
# Getting results for next zip code.. there are 4 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95472
# -----------------------------------------
# Data retrieval for 95472 complete
# Getting results for next zip code.. there are 3 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95473
# -----------------------------------------
# Data retrieval for 95473 complete
# Getting results for next zip code.. there are 2 zips left
# -----------------------------------------
# Now processing query set 1 of max 20 for 95476
# -----------------------------------------
# Now getting results for final zip code. Almost there!
# -----------------------------------------
# Now processing query set 1 of max 20 for 95492
# -----------------------------------------
# Full list of zip codes processed!

# %%
# Show cities_df with updated total # of restaurants
zip_df.head()
# Out:
#      Zip      City   County  Total # of Restaurants
# 0  94501  Alameda   Alameda                    7800
# 1  94502  Alameda   Alameda                     342
# 2  94706   Albany   Alameda                     719
# 3  94707   Albany   Alameda                     635
# 4  94710   Albany   Alameda                    2300

# %%
zip_df.to_csv("Resources/total_count_zipcodes.csv")
