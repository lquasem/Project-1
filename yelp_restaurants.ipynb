# %% [markdown]
# # Yelp API Restaurant Calls By City
#
# For each city listed in cities.csv, return first 1k restaurants found via yelp api and
# extract data regarding:
#
# - name
# - address & zip
# - coordinates
# - rating
# - review count
# - price level
# - category
# - yelp id
#
# Write data to restaurant_data.csv

# %%
# Dependencies
from __future__ import print_function
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import csv
import urllib

import argparse

import pprint
import sys

#Import API key
#from api_keys import api_key

# %% [markdown]
# ### Perform API calls
#
# - Dataframe from cities.csv
# - Build function that calls and writes restaurant data to new csv, given a city
# - Run list of cities through function

# %%
# Create dataframe from csv file
cities_df = pd.read_csv("../Resources/cities.csv", names=["City", "County", "Population", "Area (sq. mi)"])
cities_df.head()
# Out:
#               City        County Population  Area (sq. mi)
# 0          Alameda       Alameda     73,812          10.61
# 1           Albany       Alameda     18,539           1.79
# 2  American Canyon          Napa     19,454           4.84
# 3          Antioch  Contra Costa    102,372          28.35
# 4         Atherton     San Mateo      6,914           5.02

# %%
cities = cities_df["City"]
cities_ca = []
for city in cities:
    cities_ca.append(city + str(', CA'))
print(cities_ca)
# Out:
# ['Alameda, CA', 'Albany, CA', 'American Canyon, CA', 'Antioch, CA', 'Atherton, CA', 'Belmont, CA', 'Belvedere, CA', 'Benicia, CA', 'Berkeley, CA', 'Brentwood, CA', 'Brisbane, CA', 'Burlingame, CA', 'Calistoga, CA', 'Campbell, CA', 'Clayton, CA', 'Cloverdale, CA', 'Colma, CA', 'Concord, CA', 'Corte Madera, CA', 'Cotati, CA', 'Cupertino, CA', 'Daly City, CA', 'Danville, CA', 'Dixon, CA', 'Dublin, CA', 'East Palo Alto, CA', 'El Cerrito, CA', 'Emeryville, CA', 'Fairfax, CA', 'Fairfield, CA', 'Foster City, CA', 'Fremont, CA', 'Gilroy, CA', 'Half Moon Bay, CA', 'Hayward, CA', 'Healdsburg, CA', 'Hercules, CA', 'Hillsborough, CA', 'Lafayette, CA', 'Larkspur, CA', 'Livermore, CA', 'Los Altos, CA', 'Los Altos Hills, CA', 'Los Gatos, CA', 'Martinez, CA', 'Menlo Park, CA', 'Mill Valley, CA', 'Millbrae, CA', 'Milpitas, CA', 'Monte Sereno, CA', 'Moraga, CA', 'Morgan Hill, CA', 'Mountain View, CA', 'Napa, CA', 'Newark, CA', 'Novato, CA', 'Oakland, CA', 'Oakley, CA', 'Orinda, CA', 'Pacifica, CA', 'Palo Alto, CA', 'Petaluma, CA', 'Piedmont, CA', 'Pinole, CA', 'Pittsburg, CA', 'Pleasant Hill, CA', 'Pleasanton, CA', 'Portola Valley, CA', 'Redwood City, CA', 'Richmond, CA', 'Rio Vista, CA', 'Rohnert Park, CA', 'Ross, CA', 'St. Helena, CA', 'San Anselmo, CA', 'San Bruno, CA', 'San Carlos, CA', 'San Francisco, CA', 'San Jose, CA', 'San Leandro, CA', 'San Mateo, CA', 'San Pablo, CA', 'San Rafael, CA', 'San Ramon, CA', 'Santa Clara, CA', 'Santa Rosa, CA', 'Saratoga, CA', 'Sausalito, CA', 'Sebastopol, CA', 'Sonoma, CA', 'South San Francisco, CA', 'Suisun City, CA', 'Sunnyvale, CA', 'Tiburon, CA', 'Union City, CA', 'Vacaville, CA', 'Vallejo, CA', 'Walnut Creek, CA', 'Windsor, CA', 'Woodside, CA', 'Yountville, CA']

# %%
api_key = "xd2SNzqqJzdLbEq_PaLOrIg8X7ExYGvchzMSgHxV1_MzmCK-9eCg1DnBEz8epku-GUjgs3yDQ0vhgR1WVphaDxwvI7m-_1gm0Ixrt6jcnXi2eFsHDRzS4RUhbp0bXXYx"
url = "https://api.yelp.com/v3/businesses/search"
headers = {"Authorization": "Bearer %s" % api_key}
params = {"term": "restaurants", "location":cities_ca[0], "limit":5, 'offset':5}
req = requests.get(url, headers=headers, params=params).json()

# %%
yelp_data = []
counter = 0

for city in cities_ca:
    for offset in range(0, 1000, 50):
            params = {"term": "restaurants", "location": str(city), "limit":50, 'offset':offset}
            req = requests.get(url, params=params, headers=headers).json()
            if len(req["businesses"])>0:
                for business in req['businesses']:
                    counter = counter+1
                    business_dic = {}
                    if 'name' in business:

                        business_dic['name'] = business['alias']
                    else:
                        business_dic['name'] = "NAN"

                    business_dic['categories'] = []

                    for category in business['categories']:
                        if 'title' in category:
                            business_dic['categories'].append(category['title'])
                    if 'coordinates' in business: 
                        if 'latitude' in business['coordinates']:
                            business_dic['lat'] = business['coordinates']['latitude']
                        else:
                            business_dic['lat'] = "NAN"
                        if 'longitude' in business['coordinates']:
                            business_dic['lon'] = business['coordinates']['longitude']
                        else:
                            business_dic['lon'] = 'NAN'
                    if 'location' in business:
                        if 'city' in business['location']:
                            business_dic['city'] = business['location']['city']
                        else:
                            business_dic['city'] = "NAN"
                        if 'zip_code' in business['location']:
                            business_dic['zip_code'] = business['location']['zip_code']
                        else:
                            business_dic['zip_code'] = "NAN"
                        if 'state' in  business['location']:
                            business_dic['state'] = business['location']['state']
                        else:
                            business_dic['state'] = "NAN"
                    if 'price' in business:
                        business_dic['price'] = business['price']
                    else:
                        business_dic['price'] = "NAN"
                    if 'rating' in business:
                        business_dic['rating'] = business['rating']
                    else:
                        business_dic['rating'] = "NAN"
                    if 'review_count' in business:
                        business_dic['review_count'] = business['review_count']
                    else:
                        business_dic['review_count'] = "NAN"
                    yelp_data.append(business_dic)
            else: 
                print("Data not found " +  str(city) + " " + str(offset))
                break
 
print(len(yelp_data))
# Out:
# Data not found Albany, CA 250
# Data not found American Canyon, CA 300
# Data not found Antioch, CA 600
# Data not found Atherton, CA 600
# Data not found Belmont, CA 450
# Data not found Belvedere, CA 100
# Data not found Benicia, CA 400
# Data not found Brentwood, CA 300
# Data not found Brisbane, CA 400
# Data not found Calistoga, CA 50
# Data not found Clayton, CA 300
# Data not found Cloverdale, CA 50
# Data not found Colma, CA 200
# Data not found Corte Madera, CA 100
# Data not found Cotati, CA 200
# Data not found Danville, CA 300
# Data not found Dixon, CA 500
# Data not found Dublin, CA 600
# Data not found East Palo Alto, CA 400
# Data not found El Cerrito, CA 500
# Data not found Fairfax, CA 50
# Data not found Fairfield, CA 400
# Data not found Foster City, CA 350
# Data not found Gilroy, CA 500
# Data not found Half Moon Bay, CA 100
# Data not found Healdsburg, CA 150
# Data not found Hercules, CA 150
# Data not found Larkspur, CA 300
# Data not found Livermore, CA 800
# Data not found Martinez, CA 150
# Data not found Mill Valley, CA 450
# Data not found Millbrae, CA 500
# Data not found Monte Sereno, CA 150
# Data not found Moraga, CA 700
# Data not found Morgan Hill, CA 200
# Data not found Napa, CA 500
# Data not found Newark, CA 800
# Data not found Novato, CA 650
# Data not found Oakley, CA 300
# Data not found Orinda, CA 100
# Data not found Petaluma, CA 250
# Data not found Pinole, CA 250
# Data not found Pleasant Hill, CA 800
# Data not found Pleasanton, CA 500
# Data not found Portola Valley, CA 600
# Data not found Rio Vista, CA 50
# Data not found Rohnert Park, CA 200
# Data not found Ross, CA 100
# Data not found St. Helena, CA 100
# Data not found San Anselmo, CA 100
# Data not found San Bruno, CA 550
# Data not found San Carlos, CA 500
# Data not found San Pablo, CA 350
# Data not found San Rafael, CA 950
# Data not found San Ramon, CA 550
# Data not found Santa Rosa, CA 800
# Data not found Sausalito, CA 150
# Data not found Sebastopol, CA 850
# Data not found Sonoma, CA 150
# Data not found Suisun City, CA 600
# Data not found Tiburon, CA 550
# Data not found Vacaville, CA 250
# Data not found Vallejo, CA 400
# Data not found Windsor, CA 200
# Data not found Woodside, CA 600
# Data not found Yountville, CA 50
# 57567

# %%
yelp_data = pd.DataFrame(yelp_data)
yelp_data
# Out:
#                                               categories        city  \
# 0                                     [Barbeque, Korean]     Alameda
# 1                                           [Vietnamese]     Alameda
# 2                                [Mediterranean, Afghan]     Alameda
# 3                                               [German]     Alameda
# 4                               [Italian, Cocktail Bars]     Alameda
# 5                      [Cajun/Creole, Hawaiian, Seafood]     Alameda
# 6                 [Cajun/Creole, Noodles, Chicken Wings]     Alameda
# 7                            [Chinese, Noodles, Burgers]     Alameda
# 8                                           [Vietnamese]     Alameda
# 9                           [Burgers, Sandwiches, Salad]     Alameda
# 10                               [Moroccan, Salad, Soup]     Alameda
# 11                                             [Burmese]     Alameda
# 12                                  [Cambodian, Seafood]     Alameda
# 13                                    [Korean, Barbeque]     Alameda
# 14                                [Halal, Mediterranean]     Alameda
# 15                                    [Dim Sum, Seafood]     Alameda
# 16                 [Breakfast & Brunch, Donuts, Burgers]     Alameda
# 17                   [Latin American, Sandwiches, Tacos]     Alameda
# 18                                [Sushi Bars, Japanese]     Alameda
# 19                             [Poke, Hawaiian, Seafood]     Alameda
# 20           [American (New), Whiskey Bars, Steakhouses]     Alameda
# 21     [Comfort Food, Asian Fusion, Ice Cream & Froze...     Alameda
# 22                      [Greek, Italian, American (New)]     Alameda
# 23                                                [Thai]     Oakland
# 24         [American (New), Breakfast & Brunch, Burgers]     Alameda
# 25                                  [Asian Fusion, Pubs]     Alameda
# 26         [Coffee & Tea, Modern European, Beer Gardens]     Alameda
# 27                           [Chinese, Seafood, Noodles]     Oakland
# 28                       [Izakaya, Cocktail Bars, Ramen]     Oakland
# 29               [Cocktail Bars, American (Traditional)]     Oakland
# ...                                                  ...         ...
# 57537                     [American (New), Comfort Food]  Yountville
# 57538                                           [French]  Yountville
# 57539  [French, Venues & Event Spaces, Breakfast & Br...  Yountville
# 57540     [Latin American, American (New), Puerto Rican]  Yountville
# 57541              [American (New), Burgers, Sushi Bars]  Yountville
# 57542                             [Pizza, Italian, Bars]  Yountville
# 57543                                   [American (New)]  Yountville
# 57544                                           [French]  Yountville
# 57545                                   [Pizza, Italian]  Yountville
# 57546                             [Italian, Pizza, Bars]  Yountville
# 57547  [American (New), Barbeque, Venues & Event Spaces]  Yountville
# 57548                                   [American (New)]        Napa
# 57549                        [American (New), Wine Bars]        Napa
# 57550                                          [Mexican]  Yountville
# 57551                     [Bakeries, French, Sandwiches]  Yountville
# 57552        [American (New), Champagne Bars, Wine Bars]  Yountville
# 57553                 [Coffee & Tea, Breakfast & Brunch]  Yountville
# 57554                                   [American (New)]  Yountville
# 57555  [Breakfast & Brunch, American (Traditional), H...  Yountville
# 57556                                [Delis, Sandwiches]  Yountville
# 57557                               [Food Trucks, Pizza]  St. Helena
# 57558                       [American (New), Wine Tours]        Napa
# 57559                  [Food Trucks, Caterers, Barbeque]        Napa
# 57560                               [Food Trucks, Wraps]        Napa
# 57561                               [Food Trucks, Tacos]     Vallejo
# 57562                    [Coffee & Tea, Cafes, Desserts]  Yountville
# 57563                           [Food Trucks, Caribbean]   Pittsburg
# 57564                             [Food Trucks, Mexican]  Santa Rosa
# 57565                             [Mexican, Food Trucks]  Sacramento
# 57566                            [Hawaiian, Food Trucks]   Roseville
#
#              lat         lon                                         name  \
# 0      37.757548 -122.252010                    ohgane-korean-bbq-alameda
# 1      37.762117 -122.244805                         made-pho-you-alameda
# 2      37.767478 -122.239856                      angelas-kitchen-alameda
# 3      37.766060 -122.239970                         speisekammer-alameda
# 4      37.757312 -122.251694       trabocco-kitchen-and-cocktails-alameda
# 5      37.765950 -122.242500                      hang-ten-boiler-alameda
# 6      37.768258 -122.239336           monkey-king-at-the-brewery-alameda
# 7      37.762010 -122.244910                          wild-ginger-alameda
# 8      37.762932 -122.245072                       sidestreet-pho-alameda
# 9      37.762816 -122.244189                             scolaris-alameda
# 10     37.766354 -122.288017            abigails-moroccan-cuisine-alameda
# 11     37.763690 -122.243440                    burma-superstar-alameda-2
# 12     37.773850 -122.276460                phnom-penh-restaurant-alameda
# 13     37.757566 -122.252191                           bowl-d-bbq-alameda
# 14     37.764514 -122.243903       qs-halal-mediterranean-comfort-alameda
# 15     37.776719 -122.276803        east-ocean-seafood-restaurant-alameda
# 16     37.764029 -122.243002                        homeskillet-alameda-2
# 17     37.763550 -122.243550                      cholita-linda-alameda-8
# 18     37.761635 -122.245466                              yojimbo-alameda
# 19     37.763861 -122.242944                            poke-koma-alameda
# 20     37.765810 -122.242300                         american-oak-alameda
# 21     37.762848 -122.245206                        roll-and-bowl-alameda
# 22     37.769991 -122.238250               the-park-street-tavern-alameda
# 23     37.794147 -122.275524       farmhouse-kitchen-thai-cuisine-oakland
# 24     37.774799 -122.276640                      ck-restaurant-alameda-2
# 25     37.762970 -122.244070             monkey-king-pub-and-grub-alameda
# 26     37.762068 -122.244925       mama-papa-lithuania-restaurant-alameda
# 27     37.800607 -122.269862                  shandong-restaurant-oakland
# 28     37.808280 -122.272850                              shinmai-oakland
# 29     37.807491 -122.270034                            heres-how-oakland
# ...          ...         ...                                          ...
# 57537  38.399390 -122.358140                          ad-hoc-yountville-4
# 57538  38.404420 -122.364760                    french-laundry-yountville
# 57539  38.402572 -122.362025                           bouchon-yountville
# 57540  38.400040 -122.359020               protéa-restaurant-yountville-2
# 57541  38.406420 -122.367596                       r-d-kitchen-yountville
# 57542  38.405834 -122.367111                         redd-wood-yountville
# 57543  38.405558 -122.366888          rh-yountville-restaurant-yountville
# 57544  38.401030 -122.359790                     bistro-jeanty-yountville
# 57545  38.406700 -122.366830                            ciccio-yountville
# 57546  38.401651 -122.362521                            ottimo-yountville
# 57547  38.399528 -122.358516                          addendum-yountville
# 57548  38.418954 -122.388218                          mustards-grill-napa
# 57549  38.416100 -122.386690                                  brix-napa-6
# 57550  38.402160 -122.361200                        la-calenda-yountville
# 57551  38.402446 -122.361858                    bouchon-bakery-yountville
# 57552  38.402735 -122.361132         lucy-restaurant-and-bar-yountville-2
# 57553  38.406200 -122.366410                    southside-cafe-yountville
# 57554  38.397454 -122.357175                    heritage-oak-yountville-2
# 57555  38.396912 -122.360222                the-lakeside-grill-yountville
# 57556  38.400770 -122.359410                   yountville-deli-yountville
# 57557  38.506296 -122.469455                  napa-valley-crust-st-helena
# 57558  38.302398 -122.283715                  napa-valley-wine-train-napa
# 57559  38.297131 -122.286438                       deep-smoke-napa-napa-2
# 57560  38.318649 -122.299942                   phat-salads-and-wraps-napa
# 57561  38.115436 -122.254156              la-cuchara-de-doña-rosa-vallejo
# 57562  38.393827 -122.365115                       hereos-cafe-yountville
# 57563  38.011279 -121.876098               fiya-spice-caribbean-pittsburg
# 57564  38.429130 -122.734330  tortas-gigantes-metro-balderas-2-santa-rosa
# 57565  38.581572 -121.494400          zintzuni-cocina-mexicana-sacramento
# 57566  38.736900 -121.267288                   808-island-grill-roseville
#
#       price  rating  review_count state zip_code
# 0        $$     4.5            72    CA    94501
# 1       NAN     4.5            29    CA    94501
# 2        $$     4.5           204    CA    94501
# 3        $$     4.0          1317    CA    94501
# 4        $$     4.0          1157    CA    94501
# 5        $$     4.0          1078    CA    94501
# 6        $$     4.0           293    CA    94501
# 7        $$     4.0           251    CA    94501
# 8        $$     4.0           745    CA    94501
# 9        $$     4.0           992    CA    94501
# 10        $     4.5           358    CA    94501
# 11       $$     4.0          1828    CA    94501
# 12       $$     4.5           896    CA    94501
# 13       $$     4.0           432    CA    94501
# 14        $     4.5           611    CA    94501
# 15       $$     4.0          1407    CA    94501
# 16       $$     4.0           555    CA    94501
# 17       $$     4.5           181    CA    94501
# 18       $$     4.0          1327    CA    94501
# 19       $$     4.5           369    CA    94501
# 20       $$     4.0           566    CA    94501
# 21        $     4.5            61    CA    94501
# 22       $$     4.5           108    CA    94501
# 23       $$     4.0           561    CA    94607
# 24       $$     4.0           107    CA    94501
# 25       $$     3.5          1047    CA    94501
# 26       $$     4.5           524    CA    94501
# 27       $$     4.0          2719    CA    94607
# 28       $$     4.0           698    CA    94612
# 29      NAN     4.5            23    CA    94612
# ...     ...     ...           ...   ...      ...
# 57537   $$$     4.0          2753    CA    94599
# 57538  $$$$     4.5          2489    CA    94599
# 57539   $$$     4.0          2838    CA    94599
# 57540    $$     4.5           263    CA    94599
# 57541    $$     4.0          1261    CA    94599
# 57542    $$     4.0           695    CA    94599
# 57543   $$$     4.5            75    CA    94599
# 57544   $$$     4.0          1884    CA    94599
# 57545    $$     4.0           345    CA    94599
# 57546    $$     4.0            95    CA    94599
# 57547    $$     4.0           535    CA    94599
# 57548   $$$     4.0          1966    CA    94558
# 57549   $$$     4.0          1176    CA    94558
# 57550    $$     3.5           132    CA    94599
# 57551    $$     4.0          3032    CA    94599
# 57552   $$$     4.0           308    CA    94599
# 57553    $$     4.5            85    CA    94599
# 57554    $$     3.5            29    CA    94599
# 57555    $$     3.5            29    CA    94599
# 57556     $     3.5           145    CA    94599
# 57557   NAN     4.5            10    CA    94574
# 57558  $$$$     4.0          1281    CA    94559
# 57559   NAN     4.5             3    CA    94581
# 57560     $     4.0            48    CA    94558
# 57561    $$     4.5             7    CA    94590
# 57562   NAN     1.0             3    CA    94599
# 57563   NAN     5.0             1    CA    94565
# 57564     $     3.5             3    CA    95407
# 57565   NAN     4.5            38    CA    95828
# 57566   NAN     5.0            16    CA    95661
#
# [57567 rows x 10 columns]

# %%
# Save restaurants counts to csv
yelp_data.to_csv("yelp_rawdata_bycities.csv")

# %%
yelp_data.count()
# Out:
# categories      57567
# city            57567
# lat             57561
# lon             57561
# name            57567
# price           57567
# rating          57567
# review_count    57567
# state           57567
# zip_code        57567
# dtype: int64

# %%
yelp_data['city'].value_counts()
# Out:
# Oakland                    4712
# San Francisco              3961
# San Jose                   3954
# Palo Alto                  2003
# San Mateo                  1691
# Redwood City               1638
# Sunnyvale                  1592
# Berkeley                   1499
# Mountain View              1437
# Santa Clara                1420
# Fremont                    1376
# Concord                    1369
# Walnut Creek               1218
# South San Francisco        1059
# Santa Rosa                  915
# Cupertino                   891
# Pleasanton                  888
# Hayward                     836
# San Rafael                  833
# San Bruno                   807
# Vallejo                     797
# Burlingame                  746
# Menlo Park                  723
# Vacaville                   650
# Dublin                      640
# San Carlos                  613
# Richmond                    589
# Alameda                     589
# Antioch                     566
# Campbell                    558
#                            ...
# Ignacio                       2
# Elland                        2
# St Helena                     2
# Lagunitas                     2
# Travis AFB                    2
# Buda                          2
# Royal Oaks                    2
# Woodacre                      2
# Point Richmond                2
# Arlington                     2
# Lagunitas-Forest Knolls       2
# Monterrey                     1
# Cabot                         1
# Salinas                       1
# Gilroy Ca                     1
# Manila                        1
# AK                            1
# San  Jose                     1
# Royal oaks                    1
# Dillon Beach                  1
# Leicester                     1
# Thiers                        1
# Espanola                      1
# Ashland                       1
# Angwin                        1
# Marin County                  1
# Woodland                      1
# Rocklin                       1
# San Jose City                 1
# Kissimmee                     1
# Name: city, Length: 233, dtype: int64

# %%
yelp_data['categories'].value_counts()
# Out:
# [Mexican]                                               3153
# [Chinese]                                               1819
# [Pizza]                                                 1373
# [Thai]                                                   899
# [Japanese, Sushi Bars]                                   708
# [Vietnamese]                                             698
# [Italian]                                                613
# [Indian]                                                 603
# [American (New)]                                         592
# [Sandwiches, Fast Food]                                  576
# [Sushi Bars, Japanese]                                   527
# [Cafes]                                                  476
# [Japanese]                                               425
# [Food Trucks, Mexican]                                   416
# [Korean]                                                 406
# [Burgers, Fast Food]                                     372
# [Burgers]                                                362
# [Fast Food, Burgers]                                     359
# [Pizza, Italian]                                         348
# [American (Traditional)]                                 341
# [Sandwiches]                                             292
# [Mexican, Food Trucks]                                   276
# [Ramen]                                                  271
# [Mexican, Fast Food]                                     271
# [Delis]                                                  255
# [Filipino]                                               254
# [Food Trucks, Tacos]                                     238
# [Chinese, Fast Food]                                     230
# [Restaurants]                                            221
# [Fast Food, Burgers, Coffee & Tea]                       206
#                                                         ...
# [Cafes, American (Traditional), Coffee & Tea]              1
# [Indian, Lounges]                                          1
# [Caterers, Personal Chefs, Pop-Up Restaurants]             1
# [Bakeries, Coffee & Tea, Austrian]                         1
# [Juice Bars & Smoothies, Sandwiches, Food Stands]          1
# [Buffets, Sports Bars, American (New)]                     1
# [Vietnamese, Breakfast & Brunch, Cafes]                    1
# [Hot Dogs, German, Beer Bar]                               1
# [Hot Dogs, Food Trucks, Caterers]                          1
# [Taiwanese, Desserts, Cafes]                               1
# [Sports Bars, American (New), Venues & Event Spaces]       1
# [Jazz & Blues, Steakhouses, Seafood]                       1
# [American (New), Bars, Jazz & Blues]                       1
# [Sushi Bars, Food Trucks, Hawaiian]                        1
# [Bakeries, French, Patisserie/Cake Shop]                   1
# [Pizza, American (Traditional), Sandwiches]                1
# [Sandwiches, Breakfast & Brunch, Desserts]                 1
# [Pubs, Burgers, Beer Bar]                                  1
# [Asian Fusion, Thai, Vietnamese]                           1
# [Izakaya, Sushi Bars]                                      1
# [Pizza, Gluten-Free, Vegetarian]                           1
# [Salad, Sandwiches, Cafes]                                 1
# [Burgers, Irish Pub]                                       1
# [Karaoke, Sports Bars, American (New)]                     1
# [Food Court, Gluten-Free]                                  1
# [Wine Bars, Indian, Breakfast & Brunch]                    1
# [American (New), Seafood, Fast Food]                       1
# [American (New), Cocktail Bars, Sushi Bars]                1
# [Tacos, Beer Bar, Pop-Up Restaurants]                      1
# [Chinese, Seafood, Mongolian]                              1
# Name: categories, Length: 5164, dtype: int64

# %%
yelp_data['price'].value_counts()
# Out:
# $$      30808
# $       18298
# NAN      6251
# $$$      1859
# $$$$      349
# ££          2
# Name: price, dtype: int64

# %%
len(yelp_data['name'])
# Out:
# 57567

# %%
yelp_data["zip_code"].unique()
# Out:
# array(['94501', '94607', '94612', '94601', '94609', '94606', '94577',
#        '94611', '94610', '94602', '94618', '94608', '94621', '94619',
#        '94605', '94603', '94703', '94502', '', '94541', '94103', '94620',
#        '94105', '95616', '94516', '94660', '94706', '94530', '94707',
#        '94710', '94704', '94702', '94070', '91007', '94804', '94701',
#        '94709', '94110', '94538', '94558', '94565', '94560', '94066',
#        '95209', '94808', '95120', '95811', '95841', '94503', '94590',
#        '94589', '94559', '94591', '94592', '94806', '94581', '94534',
#        '95204', '95661', '94509', '94531', '94561', '94513', '94571',
#        '94521', '94514', '94511', '94517', '94505', '94519', '94518',
#        '94568', '95641', '94548', 'BS4 4WW', '94526', '94520', '94025',
#        '94301', '94063', '94061', '94304', '94306', '94062', '94305',
#        '94303', '94309', '94040', '94002', '94043', '95127', '95112',
#        '95051', '95054', '94089', '94404', '94085', '76520', '94036',
#        '94080', '94539', '95050', '94544', '95134', '95131', '95132',
#        '95116', '94014', '94158', '94107', '94124', '95110', '95133',
#        '95135', '95376', '94403', '94402', '94065', '91362', '94407',
#        '94010', '94497', '94071', '94920', '94965', '94941', '94966',
#        '94510', '94569', '94553', '94525', '94705', '94720', '94130',
#        '94563', '94805', '94005', '94134', '94112', '94015', '94016',
#        '94188', '94083', '94019', '49047', '94030', '94401', '94128',
#        '94127', '94096', '94515', '94574', '95407', '95008', '95030',
#        '95130', '95125', '95124', '95129', '95128', '95070', '95032',
#        '95117', '95014', '95126', '92008', '95118', '95113', '95123',
#        '94087', '95136', '95122', '95033', '94086', '95111', '95015',
#        '3121', '95009', '95109', '95053', '1550', '94598', '94596',
#        '95425', '95441', '94044', '94102', '63300', '94523', '94549',
#        '94597', '94595', '94556', '94507', '94506', '72802', '94939',
#        '94925', '94904', '94901', '94903', '94949', '89122', '94928',
#        '94931', '94951', '94926', '94952', '94022', '94041', '94024',
#        '48239', '94116', '94132', '94117', '94122', '94114', '94131',
#        '94583', '94582', '94683', '95620', '95694', '95687', '95688',
#        '95618', '95625', '95696', '94533', '95695', '78610', '95828',
#        '94535', '95814', '95758', '95835', '95677', '94588', '94566',
#        '94550', '94551', '94302', '94801', 'KT1 4DB', '94875', '94930',
#        '94960', '94585', '76017', '94555', '94536', '94587', '94546',
#        '95035', '94586', '94545', '94578', '94579', '94552', '94580',
#        '95025', '95020', '95037', '95046', '95045', '95023', '95004',
#        '95076', '95019', '95021', '95077', '95065', '93905', '95060',
#        '94038', '94018', '94037', '94542', '94543', '95448', '95492',
#        '95401', '94547', '94564', '77494', '94803', '94572', '95464',
#        '94820', '94708', '94957', '78130', '94028', '94023', '94035',
#        '64440', '43050', '95173', '96070', '94970', '95002', '94088',
#        '94123', '94613', '34747', '94573', '95476', '94599', '94562',
#        '95477', '95433', '72023', '07175', '94947', '94945', '94998',
#        '94954', '94938', '94946', '94933', '94963', '94973', '048582',
#        '94133', '94111', '94109', '94115', '94108', '94104', '5000',
#        '94118', '94121', '92011', '94129', '95452', '94508', '95140',
#        '95121', '95139', '95138', '95148', '95119', '95106', '94576',
#        'LE7 1GZ', 'HX5 0BB', '94924', '95404', '95405', '95409', '95403',
#        '95436', '95472', '95444', '95473', '95406', '95442', '95402',
#        '95446', '95465', '94929', '94922', '94972', '94971', '94923',
#        '95462', '87532'], dtype=object)
