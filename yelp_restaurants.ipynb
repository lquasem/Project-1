# %% [markdown]
# # Yelp API Restaurant Calls By City
#
# For each city listed in cities.csv, return first 1k restaurants found via yelp api and
# extract data regarding:
#
# - name
# - address & zip
# - coordinates
# - rating
# - review count
# - price level
# - category
# - yelp id
#
# Write data to restaurant_data.csv

# %%
# Dependencies
from __future__ import print_function
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import csv
import urllib

import argparse

import pprint
import sys

#Import API key
from api_keys import api_key

# %% [markdown]
# ### Perform API calls
#
# - Dataframe from cities.csv
# - Build function that calls and writes restaurant data to new csv, given a city
# - Run list of cities through function

# %%
# Create dataframe from csv file
cities_df = pd.read_csv("Resources/cities.csv", names=["City", "County", "Population", "Area (sq. mi)"])
cities_df.head()
# Out:
#               City        County Population  Area (sq. mi)
# 0          Alameda       Alameda     73,812          10.61
# 1           Albany       Alameda     18,539           1.79
# 2  American Canyon          Napa     19,454           4.84
# 3          Antioch  Contra Costa    102,372          28.35
# 4         Atherton     San Mateo      6,914           5.02

# %%
cities = cities_df["City"]
cities_ca = []
for city in cities:
    cities_ca.append(city + str(', CA'))
print(cities_ca)
# Out:
# ['Alameda, CA', 'Albany, CA', 'American Canyon, CA', 'Antioch, CA', 'Atherton, CA', 'Belmont, CA', 'Belvedere, CA', 'Benicia, CA', 'Berkeley, CA', 'Brentwood, CA', 'Brisbane, CA', 'Burlingame, CA', 'Calistoga, CA', 'Campbell, CA', 'Clayton, CA', 'Cloverdale, CA', 'Colma, CA', 'Concord, CA', 'Corte Madera, CA', 'Cotati, CA', 'Cupertino, CA', 'Daly City, CA', 'Danville, CA', 'Dixon, CA', 'Dublin, CA', 'East Palo Alto, CA', 'El Cerrito, CA', 'Emeryville, CA', 'Fairfax, CA', 'Fairfield, CA', 'Foster City, CA', 'Fremont, CA', 'Gilroy, CA', 'Half Moon Bay, CA', 'Hayward, CA', 'Healdsburg, CA', 'Hercules, CA', 'Hillsborough, CA', 'Lafayette, CA', 'Larkspur, CA', 'Livermore, CA', 'Los Altos, CA', 'Los Altos Hills, CA', 'Los Gatos, CA', 'Martinez, CA', 'Menlo Park, CA', 'Mill Valley, CA', 'Millbrae, CA', 'Milpitas, CA', 'Monte Sereno, CA', 'Moraga, CA', 'Morgan Hill, CA', 'Mountain View, CA', 'Napa, CA', 'Newark, CA', 'Novato, CA', 'Oakland, CA', 'Oakley, CA', 'Orinda, CA', 'Pacifica, CA', 'Palo Alto, CA', 'Petaluma, CA', 'Piedmont, CA', 'Pinole, CA', 'Pittsburg, CA', 'Pleasant Hill, CA', 'Pleasanton, CA', 'Portola Valley, CA', 'Redwood City, CA', 'Richmond, CA', 'Rio Vista, CA', 'Rohnert Park, CA', 'Ross, CA', 'St. Helena, CA', 'San Anselmo, CA', 'San Bruno, CA', 'San Carlos, CA', 'San Francisco, CA', 'San Jose, CA', 'San Leandro, CA', 'San Mateo, CA', 'San Pablo, CA', 'San Rafael, CA', 'San Ramon, CA', 'Santa Clara, CA', 'Santa Rosa, CA', 'Saratoga, CA', 'Sausalito, CA', 'Sebastopol, CA', 'Sonoma, CA', 'South San Francisco, CA', 'Suisun City, CA', 'Sunnyvale, CA', 'Tiburon, CA', 'Union City, CA', 'Vacaville, CA', 'Vallejo, CA', 'Walnut Creek, CA', 'Windsor, CA', 'Woodside, CA', 'Yountville, CA']

# %%
url = "https://api.yelp.com/v3/businesses/search"
headers = {"Authorization": "Bearer %s" % api_key}
params = {"term": "restaurants", "location":cities_ca[0], "limit":5, 'offset':5}
req = requests.get(url, headers=headers, params=params).json()

# %%
yelp_data = []
counter = 0

for city in cities_ca:
    for offset in range(0, 1000, 50):
            params = {"term": "restaurants", "location": str(city), "limit":50, 'offset':offset}
            req = requests.get(url, params=params, headers=headers).json()
            if len(req["businesses"])>0:
                for business in req['businesses']:
                    counter = counter+1
                    business_dic = {}
                    if 'name' in business:

                        business_dic['name'] = business['alias']
                    else:
                        business_dic['name'] = "NAN"

                    business_dic['categories'] = []

                    for category in business['categories']:
                        if 'title' in category:
                            business_dic['categories'].append(category['title'])
                    if 'coordinates' in business: 
                        if 'latitude' in business['coordinates']:
                            business_dic['lat'] = business['coordinates']['latitude']
                        else:
                            business_dic['lat'] = "NAN"
                        if 'longitude' in business['coordinates']:
                            business_dic['lon'] = business['coordinates']['longitude']
                        else:
                            business_dic['lon'] = 'NAN'
                    if 'location' in business:
                        if 'city' in business['location']:
                            business_dic['city'] = business['location']['city']
                        else:
                            business_dic['city'] = "NAN"
                        if 'zip_code' in business['location']:
                            business_dic['zip_code'] = business['location']['zip_code']
                        else:
                            business_dic['zip_code'] = "NAN"
                        if 'state' in  business['location']:
                            business_dic['state'] = business['location']['state']
                        else:
                            business_dic['state'] = "NAN"
                    if 'price' in business:
                        business_dic['price'] = business['price']
                    else:
                        business_dic['price'] = "NAN"
                    if 'rating' in business:
                        business_dic['rating'] = business['rating']
                    else:
                        business_dic['rating'] = "NAN"
                    if 'review_count' in business:
                        business_dic['review_count'] = business['review_count']
                    else:
                        business_dic['review_count'] = "NAN"
                    yelp_data.append(business_dic)
            else: 
                print("Data not found " +  str(city) + " " + str(offset))
                break
 
print(len(yelp_data))
# Out:
# Data not found Albany, CA 250
# Data not found American Canyon, CA 300
# Data not found Antioch, CA 600
# Data not found Atherton, CA 600
# Data not found Belmont, CA 450
# Data not found Belvedere, CA 100
# Data not found Benicia, CA 400
# Data not found Brentwood, CA 300
# Data not found Brisbane, CA 350
# Data not found Calistoga, CA 50
# Data not found Clayton, CA 300
# Data not found Cloverdale, CA 50
# Data not found Colma, CA 200
# Data not found Corte Madera, CA 100
# Data not found Cotati, CA 200
# Data not found Danville, CA 300
# Data not found Dixon, CA 500
# Data not found Dublin, CA 600
# Data not found East Palo Alto, CA 400
# Data not found El Cerrito, CA 500
# Data not found Fairfax, CA 50
# Data not found Fairfield, CA 400
# Data not found Foster City, CA 350
# Data not found Gilroy, CA 500
# Data not found Half Moon Bay, CA 100
# Data not found Healdsburg, CA 150
# Data not found Hercules, CA 150
# Data not found Larkspur, CA 300
# Data not found Livermore, CA 800
# Data not found Martinez, CA 150
# Data not found Mill Valley, CA 450
# Data not found Millbrae, CA 450
# Data not found Monte Sereno, CA 150
# Data not found Moraga, CA 700
# Data not found Morgan Hill, CA 200
# Data not found Napa, CA 500
# Data not found Newark, CA 750
# Data not found Novato, CA 650
# Data not found Oakley, CA 300
# Data not found Orinda, CA 100
# Data not found Petaluma, CA 250
# Data not found Pinole, CA 250
# Data not found Pleasant Hill, CA 800
# Data not found Pleasanton, CA 450
# Data not found Portola Valley, CA 600
# Data not found Rio Vista, CA 50
# Data not found Rohnert Park, CA 200
# Data not found Ross, CA 100
# Data not found St. Helena, CA 100
# Data not found San Anselmo, CA 100
# Data not found San Bruno, CA 550
# Data not found San Carlos, CA 500
# Data not found San Pablo, CA 350
# Data not found San Rafael, CA 900
# Data not found San Ramon, CA 550
# Data not found Santa Rosa, CA 800
# Data not found Sausalito, CA 150
# Data not found Sebastopol, CA 850
# Data not found Sonoma, CA 150
# Data not found Suisun City, CA 600
# Data not found Tiburon, CA 550
# Data not found Vacaville, CA 250
# Data not found Vallejo, CA 350
# Data not found Windsor, CA 200
# Data not found Woodside, CA 600
# Data not found Yountville, CA 50
# 57438

# %%
yelp_data = pd.DataFrame(yelp_data)
yelp_data
# Out:
#                                               categories        city  \
# 0                                     [Barbeque, Korean]     Alameda
# 1                                           [Vietnamese]     Alameda
# 2                                [Mediterranean, Afghan]     Alameda
# 3                                               [German]     Alameda
# 4                               [Italian, Cocktail Bars]     Alameda
# 5                 [Cajun/Creole, Noodles, Chicken Wings]     Alameda
# 6      [Comfort Food, Asian Fusion, Ice Cream & Froze...     Alameda
# 7                                              [Burmese]     Alameda
# 8                            [Chinese, Noodles, Burgers]     Alameda
# 9                      [Cajun/Creole, Hawaiian, Seafood]     Alameda
# 10                                    [Korean, Barbeque]     Alameda
# 11                                [Halal, Mediterranean]     Alameda
# 12                                  [Cambodian, Seafood]     Alameda
# 13                                          [Vietnamese]     Alameda
# 14                          [Burgers, Sandwiches, Salad]     Alameda
# 15                               [Moroccan, Salad, Soup]     Alameda
# 16                                  [Asian Fusion, Pubs]     Alameda
# 17                                [Sushi Bars, Japanese]     Alameda
# 18                                                [Thai]     Oakland
# 19                                [Sushi Bars, Japanese]     Alameda
# 20                      [Greek, Italian, American (New)]     Alameda
# 21                   [Latin American, Sandwiches, Tacos]     Alameda
# 22                                                [Thai]     Alameda
# 23                                    [Dim Sum, Seafood]     Alameda
# 24           [American (New), Whiskey Bars, Steakhouses]     Alameda
# 25                   [Vietnamese, Asian Fusion, Noodles]     Alameda
# 26                             [Poke, Hawaiian, Seafood]     Alameda
# 27                                                [Thai]     Alameda
# 28                     [Sandwiches, Salad, Chicken Shop]     Alameda
# 29            [American (New), Modern European, Italian]     Alameda
# ...                                                  ...         ...
# 57408                     [American (New), Comfort Food]  Yountville
# 57409  [French, Venues & Event Spaces, Breakfast & Br...  Yountville
# 57410                                           [French]  Yountville
# 57411                                           [French]  Yountville
# 57412                                   [American (New)]  Yountville
# 57413              [American (New), Burgers, Sushi Bars]  Yountville
# 57414                             [Pizza, Italian, Bars]  Yountville
# 57415     [Latin American, American (New), Puerto Rican]  Yountville
# 57416                                   [Pizza, Italian]  Yountville
# 57417  [American (New), Barbeque, Venues & Event Spaces]  Yountville
# 57418                     [Bakeries, French, Sandwiches]  Yountville
# 57419                                          [Mexican]  Yountville
# 57420                                   [American (New)]        Napa
# 57421                             [Italian, Pizza, Bars]  Yountville
# 57422                        [American (New), Wine Bars]        Napa
# 57423        [American (New), Champagne Bars, Wine Bars]  Yountville
# 57424                 [Coffee & Tea, Breakfast & Brunch]  Yountville
# 57425                                   [American (New)]  Yountville
# 57426                                [Delis, Sandwiches]  Yountville
# 57427  [Breakfast & Brunch, American (Traditional), H...  Yountville
# 57428                               [Food Trucks, Pizza]  St. Helena
# 57429                  [Food Trucks, Caterers, Barbeque]        Napa
# 57430                       [American (New), Wine Tours]        Napa
# 57431                               [Food Trucks, Wraps]        Napa
# 57432                    [Coffee & Tea, Cafes, Desserts]  Yountville
# 57433                               [Food Trucks, Tacos]     Vallejo
# 57434                             [Food Trucks, Mexican]  Santa Rosa
# 57435                           [Food Trucks, Caribbean]   Pittsburg
# 57436                             [Mexican, Food Trucks]  Sacramento
# 57437                            [Hawaiian, Food Trucks]   Roseville
#
#              lat         lon                                         name  \
# 0      37.757548 -122.252010                    ohgane-korean-bbq-alameda
# 1      37.762117 -122.244805                         made-pho-you-alameda
# 2      37.767478 -122.239856                      angelas-kitchen-alameda
# 3      37.766060 -122.239970                         speisekammer-alameda
# 4      37.757312 -122.251694       trabocco-kitchen-and-cocktails-alameda
# 5      37.768258 -122.239336           monkey-king-at-the-brewery-alameda
# 6      37.762848 -122.245206                        roll-and-bowl-alameda
# 7      37.763690 -122.243440                    burma-superstar-alameda-2
# 8      37.762010 -122.244910                          wild-ginger-alameda
# 9      37.765950 -122.242500                      hang-ten-boiler-alameda
# 10     37.757566 -122.252191                           bowl-d-bbq-alameda
# 11     37.764514 -122.243903       qs-halal-mediterranean-comfort-alameda
# 12     37.773850 -122.276460                phnom-penh-restaurant-alameda
# 13     37.762932 -122.245072                       sidestreet-pho-alameda
# 14     37.762816 -122.244189                             scolaris-alameda
# 15     37.766354 -122.288017            abigails-moroccan-cuisine-alameda
# 16     37.762970 -122.244070             monkey-king-pub-and-grub-alameda
# 17     37.761635 -122.245466                              yojimbo-alameda
# 18     37.794147 -122.275524       farmhouse-kitchen-thai-cuisine-oakland
# 19     37.764820 -122.241970                              utzutzu-alameda
# 20     37.769991 -122.238250               the-park-street-tavern-alameda
# 21     37.763550 -122.243550                      cholita-linda-alameda-8
# 22     37.779660 -122.291000                          monkey-thai-alameda
# 23     37.776719 -122.276803        east-ocean-seafood-restaurant-alameda
# 24     37.765810 -122.242300                         american-oak-alameda
# 25     37.771290 -122.277090                     pho-and-baguette-alameda
# 26     37.763861 -122.242944                            poke-koma-alameda
# 27     37.757222 -122.252784                        monkey-thai-alameda-5
# 28     37.764798 -122.242448                lolas-chicken-shack-alameda-2
# 29     37.764320 -122.243318                                pappo-alameda
# ...          ...         ...                                          ...
# 57408  38.399390 -122.358140                          ad-hoc-yountville-4
# 57409  38.402572 -122.362025                           bouchon-yountville
# 57410  38.404420 -122.364760                    french-laundry-yountville
# 57411  38.401030 -122.359790                     bistro-jeanty-yountville
# 57412  38.405558 -122.366888          rh-yountville-restaurant-yountville
# 57413  38.406420 -122.367596                       r-d-kitchen-yountville
# 57414  38.405834 -122.367111                         redd-wood-yountville
# 57415  38.400040 -122.359020               protéa-restaurant-yountville-2
# 57416  38.406700 -122.366830                            ciccio-yountville
# 57417  38.399528 -122.358516                          addendum-yountville
# 57418  38.402446 -122.361858                    bouchon-bakery-yountville
# 57419  38.402160 -122.361200                        la-calenda-yountville
# 57420  38.418954 -122.388218                          mustards-grill-napa
# 57421  38.401651 -122.362521                            ottimo-yountville
# 57422  38.416100 -122.386690                                  brix-napa-6
# 57423  38.402735 -122.361132         lucy-restaurant-and-bar-yountville-2
# 57424  38.406200 -122.366410                    southside-cafe-yountville
# 57425  38.397454 -122.357175                    heritage-oak-yountville-2
# 57426  38.400770 -122.359410                   yountville-deli-yountville
# 57427  38.396912 -122.360222                the-lakeside-grill-yountville
# 57428  38.506296 -122.469455                  napa-valley-crust-st-helena
# 57429  38.297131 -122.286438                       deep-smoke-napa-napa-2
# 57430  38.302398 -122.283715                  napa-valley-wine-train-napa
# 57431  38.318649 -122.299942                   phat-salads-and-wraps-napa
# 57432  38.393827 -122.365115                       hereos-cafe-yountville
# 57433  38.115436 -122.254156              la-cuchara-de-doña-rosa-vallejo
# 57434  38.429130 -122.734330  tortas-gigantes-metro-balderas-2-santa-rosa
# 57435  38.011279 -121.876098               fiya-spice-caribbean-pittsburg
# 57436  38.581572 -121.494400          zintzuni-cocina-mexicana-sacramento
# 57437  38.736900 -121.267288                   808-island-grill-roseville
#
#       price  rating  review_count state zip_code
# 0        $$     4.5            51    CA    94501
# 1       NAN     4.5            22    CA    94501
# 2        $$     4.5           203    CA    94501
# 3        $$     4.0          1312    CA    94501
# 4        $$     4.0          1157    CA    94501
# 5        $$     4.0           291    CA    94501
# 6         $     4.5            58    CA    94501
# 7        $$     4.0          1827    CA    94501
# 8        $$     4.0           250    CA    94501
# 9        $$     4.0          1076    CA    94501
# 10       $$     4.0           431    CA    94501
# 11        $     4.5           609    CA    94501
# 12       $$     4.5           896    CA    94501
# 13       $$     4.0           743    CA    94501
# 14       $$     4.0           992    CA    94501
# 15        $     4.5           358    CA    94501
# 16       $$     3.5          1045    CA    94501
# 17       $$     4.0          1322    CA    94501
# 18       $$     4.0           533    CA    94607
# 19     $$$$     4.5            54    CA    94501
# 20       $$     4.5           104    CA    94501
# 21       $$     4.0           177    CA    94501
# 22       $$     4.0           371    CA    94501
# 23       $$     4.0          1403    CA    94501
# 24       $$     4.0           566    CA    94501
# 25        $     4.0           207    CA    94501
# 26       $$     4.5           369    CA    94501
# 27       $$     3.5           159    CA    94501
# 28        $     4.0           530    CA    94501
# 29      $$$     4.0           376    CA    94501
# ...     ...     ...           ...   ...      ...
# 57408   $$$     4.0          2752    CA    94599
# 57409   $$$     4.0          2836    CA    94599
# 57410  $$$$     4.5          2487    CA    94599
# 57411   $$$     4.0          1884    CA    94599
# 57412   $$$     4.5            72    CA    94599
# 57413    $$     4.0          1253    CA    94599
# 57414    $$     4.0           694    CA    94599
# 57415    $$     4.5           257    CA    94599
# 57416    $$     4.0           343    CA    94599
# 57417    $$     4.0           534    CA    94599
# 57418    $$     4.0          3027    CA    94599
# 57419    $$     3.5           126    CA    94599
# 57420   $$$     4.0          1963    CA    94558
# 57421    $$     4.0            94    CA    94599
# 57422   $$$     4.0          1169    CA    94558
# 57423   $$$     4.0           305    CA    94599
# 57424    $$     4.5            81    CA    94599
# 57425    $$     3.5            29    CA    94599
# 57426     $     3.5           145    CA    94599
# 57427    $$     3.5            29    CA    94599
# 57428   NAN     4.5            10    CA    94574
# 57429   NAN     4.5             3    CA    94581
# 57430  $$$$     4.0          1277    CA    94559
# 57431     $     4.0            48    CA    94558
# 57432   NAN     1.0             3    CA    94599
# 57433    $$     4.5             7    CA    94590
# 57434     $     3.5             3    CA    95407
# 57435   NAN     5.0             1    CA    94565
# 57436   NAN     4.5            38    CA    95828
# 57437   NAN     5.0            16    CA    95661
#
# [57438 rows x 10 columns]

# %%
yelp_data.count()
# Out:
# categories      57438
# city            57438
# lat             57431
# lon             57431
# name            57438
# price           57438
# rating          57438
# review_count    57438
# state           57438
# zip_code        57438
# dtype: int64

# %%
yelp_data['city'].value_counts()
# Out:
# Oakland                    4553
# San Jose                   3856
# San Francisco              3840
# Palo Alto                  1982
# San Mateo                  1688
# Redwood City               1630
# Sunnyvale                  1605
# Berkeley                   1523
# Santa Clara                1446
# Mountain View              1430
# Fremont                    1417
# Concord                    1392
# Walnut Creek               1247
# South San Francisco        1070
# Santa Rosa                  915
# Cupertino                   898
# Hayward                     874
# Pleasanton                  866
# San Rafael                  826
# San Bruno                   809
# Vallejo                     792
# Burlingame                  732
# Menlo Park                  715
# Vacaville                   651
# San Carlos                  626
# Richmond                    618
# Dublin                      613
# Alameda                     574
# Antioch                     563
# Campbell                    542
#                            ...
# Point Richmond                2
# So San Francisco              2
# Buda                          2
# St Helena                     2
# Leicester                     2
# Bristol                       2
# Royal Oaks                    2
# Lagunitas                     2
# Alberdi                       2
# Aromas                        2
# Travis Air Force Base         2
# Nicasio                       2
# Arlington                     2
# Lagunitas-Forest Knolls       2
# Salinas                       1
# Woodland                      1
# Kissimmee                     1
# Royal oaks                    1
# Gilroy Ca                     1
# Ashland                       1
# Dillon Beach                  1
# Angwin                        1
# Rocklin                       1
# Espanola                      1
# Monterrey                     1
# Marin County                  1
# San Jose City                 1
# San  Jose                     1
# Cabot                         1
# Thiers                        1
# Name: city, Length: 228, dtype: int64

# %%
yelp_data['categories'].value_counts()
# Out:
# [Mexican]                                                    3269
# [Chinese]                                                    1842
# [Pizza]                                                      1426
# [Thai]                                                        913
# [Vietnamese]                                                  762
# [Japanese, Sushi Bars]                                        732
# [Indian]                                                      649
# [Italian]                                                     640
# [Sandwiches, Fast Food]                                       596
# [American (New)]                                              576
# [Sushi Bars, Japanese]                                        552
# [Cafes]                                                       473
# [Japanese]                                                    448
# [Food Trucks, Mexican]                                        416
# [Korean]                                                      403
# [Burgers, Fast Food]                                          379
# [Fast Food, Burgers]                                          378
# [Burgers]                                                     363
# [Pizza, Italian]                                              361
# [American (Traditional)]                                      331
# [Sandwiches]                                                  308
# [Mexican, Food Trucks]                                        286
# [Mexican, Fast Food]                                          286
# [Filipino]                                                    270
# [Ramen]                                                       267
# [Delis]                                                       263
# [Chinese, Fast Food]                                          249
# [Food Trucks, Tacos]                                          239
# [Restaurants]                                                 229
# [Fast Food, Burgers, Coffee & Tea]                            218
#                                                              ...
# [Coffee & Tea, Italian, Bakeries]                               1
# [Cafes, Bakeries, Bubble Tea]                                   1
# [Hotels, Wine Bars, Italian]                                    1
# [Mediterranean, Sandwiches, Juice Bars & Smoothies]             1
# [Chicken Shop, Soul Food, Southern]                             1
# [Seafood, Mexican, Fish & Chips]                                1
# [Cafes, Burgers, Sandwiches]                                    1
# [Acai Bowls, Sandwiches, Juice Bars & Smoothies]                1
# [Chinese, Buffets, Sushi Bars]                                  1
# [Cafeteria, Salad, Breakfast & Brunch]                          1
# [Pizza, Personal Chefs]                                         1
# [Chinese, Sushi Bars, Noodles]                                  1
# [Meat Shops, Mexican]                                           1
# [Vietnamese, Cafes, Soup]                                       1
# [Burgers, Thai, Sandwiches]                                     1
# [Tapas/Small Plates, Mexican, Gluten-Free]                      1
# [Cafes, Coffee & Tea, Waffles]                                  1
# [Asian Fusion, Vietnamese, Thai]                                1
# [Coffee & Tea, Breakfast & Brunch, Tex-Mex]                     1
# [Hot Dogs, Food Stands, Sandwiches]                             1
# [Sandwiches, Juice Bars & Smoothies, Beer Bar]                  1
# [Diners, Cafes, Breakfast & Brunch]                             1
# [American (Traditional), Wine Bars, Tapas/Small Plates]         1
# [American (Traditional), Diners, Italian]                       1
# [Food Stands, Candy Stores]                                     1
# [Cafes, Banks & Credit Unions]                                  1
# [Restaurants, Amateur Sports Teams]                             1
# [Steakhouses, Breakfast & Brunch, American (Traditional)]       1
# [Sandwiches, Food Trucks]                                       1
# [Seafood, Burgers, Sandwiches]                                  1
# Name: categories, Length: 5125, dtype: int64

# %%
yelp_data['price'].value_counts()
# Out:
# $$      29750
# $       19130
# NAN      6294
# $$$      1888
# $$$$      374
# ££          2
# Name: price, dtype: int64

# %%
len(yelp_data['name'])
# Out:
# 57438

# %%
yelp_data["zip_code"].unique()
# Out:
# array(['94501', '94607', '94612', '94619', '94606', '94609', '94610',
#        '94601', '94611', '94602', '94577', '94605', '94608', '94618',
#        '94621', '94603', '94502', '94541', '', '94703', '94620', '94105',
#        '94103', '94660', '95616', '94110', 'LE7 1GZ', '94706', '94530',
#        '94707', '94702', '94710', '94704', '94070', '94804', '94701',
#        '94538', '94709', '94558', '94565', '94560', '95209', '94066',
#        '94808', '95811', '95841', '94503', '94589', '94590', '94591',
#        '94559', '94592', '94806', '94581', '94534', '95204', '95661',
#        '94509', '94531', '94513', '94561', '94521', '94571', '94511',
#        '94517', '94505', '94518', '94514', '94519', '94548', '95641',
#        'BS4 4WW', '94526', '94520', '94025', '94301', '94063', '94061',
#        '94306', '94304', '94305', '94062', '94303', '94040', '94309',
#        '94002', '95112', '95127', '95051', '94043', '94089', '76520',
#        '94085', '94404', '95054', '94539', '94080', '95050', '94544',
#        '94036', '95134', '95132', '95131', '94014', '95116', '94107',
#        '94158', '95110', '95133', '94124', '95135', '95376', '94403',
#        '94402', '94065', '91362', '94407', '94010', '94497', '94071',
#        '94920', '94965', '94941', '94966', '94510', '94569', '94553',
#        '94525', '94705', '94720', '94563', '94805', '94130', '94708',
#        '94005', '94134', '94112', '94015', '94016', '94188', '94083',
#        '49047', '94019', '94030', '94401', '94128', '94127', '94096',
#        '94515', '94574', '95407', '95008', '95125', '95130', '95030',
#        '95124', '95129', '95070', '95128', '95032', '95118', '95014',
#        '92008', '95117', '95126', '94087', '95113', '95122', '95136',
#        '95123', '95120', '95033', '94086', '95015', '43050', '95109',
#        '3121', '95111', '95053', '95009', '94598', '94596', '95425',
#        '95441', '94044', '94102', '63300', '94523', '94549', '94597',
#        '94556', '94595', '94507', '94506', '72802', '94123', '94925',
#        '94939', '94904', '94903', '94901', '94949', '89122', '94928',
#        '94931', '94951', '94926', '94952', '94022', '94041', '94024',
#        '48239', '94132', '94122', '94116', '94117', '94131', '94114',
#        '94583', '94582', '94683', '95620', '95694', '95687', '95618',
#        '95688', '95625', '94533', '95695', '95696', '78610', '94535',
#        '95828', '95835', '95814', '95758', '95677', '94588', '94568',
#        '94566', '94551', '94302', '94801', 'KT1 4DB', '94875', '94930',
#        '94960', '94585', '76017', '94555', '94536', '94546', '94587',
#        '95035', '94586', '94545', '94550', '94578', '94579', '94552',
#        '94580', '95025', '95020', '95037', '95046', '95045', '95004',
#        '95076', '95023', '95019', '95021', '95077', '95065', '93905',
#        '95060', '94038', '94037', '94018', '94542', '94543', '95448',
#        '95492', '95401', '94547', '94564', '94803', '94572', '95464',
#        '94820', '94516', '94957', '78130', '94028', '94023', '94035',
#        '64440', '95173', '96070', '94970', '95002', '94613', '34747',
#        '94599', '94573', '95476', '94562', '95477', '95433', '72023',
#        '07175', '94947', '94945', '94998', '94954', '94938', '94946',
#        '94933', '94963', '94973', '048582', '94133', '94111', '94109',
#        '94115', '94108', '94104', '5000', '94118', '94121', '92011',
#        '94129', '95452', '94508', '95140', '95121', '95138', '95139',
#        '95148', '95119', '95106', '94576', 'HX5 0BB', '94924', '95052',
#        '95404', '95405', '95403', '95409', '95436', '95472', '95406',
#        '95473', '95444', '95442', '95402', '95446', '95465', '94929',
#        '94922', '94972', '94923', '94971', '95462', '87532'], dtype=object)
