# %% [markdown]
# # Yelp API Restaurant Calls By GPS Coordinates
#
# For each coordinate listed in grid_coordinates.csv, return first 1k restaurants found via yelp api and
# extract data regarding:
#
# - name
# - address & zip
# - coordinates
# - rating
# - review count
# - price level
# - category
# - yelp id
#
# Write data to restaurant_data_coord.csv

# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import csv

# Import API key
from api_keys import api_key

# %% [markdown]
# ### Perform API calls
#
# - Dataframe from grid_coordinates.csv
# - Build function that calls and writes restaurant data to new csv, given pair of coordinates
# - Run list of coordinates through function

# %%
# Create dataframe from csv file
coords_df = pd.read_csv("Resources/grid_coordinates.csv", 
                        names=["Lat", "Lng"])
coords_df
# Out:
#            Lat         Lng
# 0    38.871657 -123.109843
# 1    38.871657 -123.017222
# 2    38.871657 -122.924601
# 3    38.871657 -122.831980
# 4    38.871657 -122.739359
# 5    38.871657 -122.646738
# 6    38.871657 -122.554117
# 7    38.871657 -122.461496
# 8    38.871657 -122.368875
# 9    38.871657 -122.276254
# 10   38.871657 -122.183633
# 11   38.871657 -122.091012
# 12   38.871657 -121.998391
# 13   38.871657 -121.905770
# 14   38.871657 -121.813149
# 15   38.871657 -121.720528
# 16   38.871657 -121.627907
# 17   38.871657 -121.535286
# 18   38.871657 -121.442665
# 19   38.799167 -123.109843
# 20   38.799167 -123.017222
# 21   38.799167 -122.924601
# 22   38.799167 -122.831980
# 23   38.799167 -122.739359
# 24   38.799167 -122.646738
# 25   38.799167 -122.554117
# 26   38.799167 -122.461496
# 27   38.799167 -122.368875
# 28   38.799167 -122.276254
# 29   38.799167 -122.183633
# ..         ...         ...
# 502  36.986917 -122.368875
# 503  36.986917 -122.276254
# 504  36.986917 -122.183633
# 505  36.986917 -122.091012
# 506  36.986917 -121.998391
# 507  36.986917 -121.905770
# 508  36.986917 -121.813149
# 509  36.986917 -121.720528
# 510  36.986917 -121.627907
# 511  36.986917 -121.535286
# 512  36.986917 -121.442665
# 513  36.914427 -123.109843
# 514  36.914427 -123.017222
# 515  36.914427 -122.924601
# 516  36.914427 -122.831980
# 517  36.914427 -122.739359
# 518  36.914427 -122.646738
# 519  36.914427 -122.554117
# 520  36.914427 -122.461496
# 521  36.914427 -122.368875
# 522  36.914427 -122.276254
# 523  36.914427 -122.183633
# 524  36.914427 -122.091012
# 525  36.914427 -121.998391
# 526  36.914427 -121.905770
# 527  36.914427 -121.813149
# 528  36.914427 -121.720528
# 529  36.914427 -121.627907
# 530  36.914427 -121.535286
# 531  36.914427 -121.442665
#
# [532 rows x 2 columns]

# %%
# Function returns up to 1000 restaurant listings for input coordinates
def get_restaurants(lat, lng, api_key):
    
    url = "https://api.yelp.com/v3/businesses/search"
    headers = {"Authorization": "Bearer %s" % api_key}
    restaurant_data = []
    count = 0
    
    # Increases search return limit
    for offset in range(0, 1000, 50):
        
        # Set parameters and pass into API calls, radius 8046 meters = 5 miles
        params = {"term":"restaurants", "sort_by":"rating", "latitude":lat, "longitude":lng, "radius":8046, 
                  "limit":50, "offset":offset}
        req = requests.get(url, params=params, headers=headers)
        
        # Breaks if error occurs with search
        if req.status_code == 400:
            break
        elif req.status_code == 200:
            
            # Convert to json
            response = req.json()
            
            # Log history
            count += 1
            print(f"Now processing query set {count} of max 20")
            
            # Breaks if no further entries in query
            if response["businesses"] == []:
                break
            
            else:
                # Iterate through business results and extract data
                for biz in response["businesses"]:
                    
                    # Logic to replace missing price level data with NaN
                    if "price" not in biz:
                        
                        # Replace both price & missing category data with empty string
                        if biz["categories"] == []:
                            restaurant_data.append([str(lat) + ", " + str(lng), lat, lng, biz["name"], 
                                                    biz["coordinates"]["latitude"], 
                                                    biz["coordinates"]["longitude"], 
                                                    biz["location"]["address1"], 
                                                    biz["location"]["zip_code"], biz["rating"], 
                                                    biz["review_count"], "", "", biz["id"]])
                        else:
                            restaurant_data.append([str(lat) + ", " + str(lng), lat, lng, biz["name"], 
                                                    biz["coordinates"]["latitude"], 
                                                    biz["coordinates"]["longitude"], 
                                                    biz["location"]["address1"], 
                                                    biz["location"]["zip_code"], biz["rating"], 
                                                    biz["review_count"], "", biz["categories"][0]["title"], 
                                                    biz["id"]])

                    # Replace missing category data with empty string
                    elif biz["categories"] == []:
                        restaurant_data.append([str(lat) + ", " + str(lng), lat, lng, biz["name"], biz["coordinates"]["latitude"], 
                                                biz["coordinates"]["longitude"], biz["location"]["address1"], 
                                                biz["location"]["zip_code"], biz["rating"], 
                                                biz["review_count"], biz["price"], "", biz["id"]])

                    else:
                        restaurant_data.append([str(lat) + ", " + str(lng), lat, lng, biz["name"], biz["coordinates"]["latitude"], 
                                                biz["coordinates"]["longitude"], biz["location"]["address1"], 
                                                biz["location"]["zip_code"], biz["rating"], 
                                                biz["review_count"], biz["price"], 
                                                biz["categories"][0]["title"], biz["id"]])

    # Write to csv
    with open('Resources/restaurant_data_coords_ratings.csv', 'a', encoding="utf-8") as csvFile:
        writer = csv.writer(csvFile)
        writer.writerows(restaurant_data)
    csvFile.close()
    
    # Returns total count of restaurants in coordinates
    return response["total"]

# %%
# Track # of coordinates processed
count = 0

# List to track total restaurants found in coordinate
totals_count = []

print("LOG HISTORY OF API CALLS:")
print("---------------------------")

# Loop thru list of coordinates
lat_coords = [lat for lat in coords_df["Lat"]]
lng_coords = [lng for lng in coords_df["Lng"]]

for index in range(len(lat_coords)):
                   
    #  Call get_restaurants fn and append to total_count list
    totals_count.append(get_restaurants(lat_coords[index], lng_coords[index] , api_key))
    
    # Print log history
    count += 1
    rem = len(lat_coords) - count
    print("-----------------------------------------")
    if count == len(lat_coords):
        print("Full list of coordinates processed!")
    elif count == len(lat_coords) - 1:
        print("Now getting results for final coordinates. Almost there!")
        print("-----------------------------------------")
    else:
        print(f"Data retrieval for coordinates {count} complete")
        print(f"Getting results for next coordinates.. there are {rem} left")
        print("-----------------------------------------")

coords_df["Total # of Restaurants"] = totals_count
# Out:
# LOG HISTORY OF API CALLS:
# ---------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 1 complete
# Getting results for next coordinates.. there are 531 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 2 complete
# Getting results for next coordinates.. there are 530 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 3 complete
# Getting results for next coordinates.. there are 529 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 4 complete
# Getting results for next coordinates.. there are 528 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 5 complete
# Getting results for next coordinates.. there are 527 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 6 complete
# Getting results for next coordinates.. there are 526 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 7 complete
# Getting results for next coordinates.. there are 525 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 8 complete
# Getting results for next coordinates.. there are 524 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 9 complete
# Getting results for next coordinates.. there are 523 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 10 complete
# Getting results for next coordinates.. there are 522 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 11 complete
# Getting results for next coordinates.. there are 521 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 12 complete
# Getting results for next coordinates.. there are 520 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 13 complete
# Getting results for next coordinates.. there are 519 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 14 complete
# Getting results for next coordinates.. there are 518 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 15 complete
# Getting results for next coordinates.. there are 517 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 16 complete
# Getting results for next coordinates.. there are 516 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 17 complete
# Getting results for next coordinates.. there are 515 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 18 complete
# Getting results for next coordinates.. there are 514 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 19 complete
# Getting results for next coordinates.. there are 513 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 20 complete
# Getting results for next coordinates.. there are 512 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 21 complete
# Getting results for next coordinates.. there are 511 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 22 complete
# Getting results for next coordinates.. there are 510 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 23 complete
# Getting results for next coordinates.. there are 509 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 24 complete
# Getting results for next coordinates.. there are 508 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 25 complete
# Getting results for next coordinates.. there are 507 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 26 complete
# Getting results for next coordinates.. there are 506 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 27 complete
# Getting results for next coordinates.. there are 505 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 28 complete
# Getting results for next coordinates.. there are 504 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 29 complete
# Getting results for next coordinates.. there are 503 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 30 complete
# Getting results for next coordinates.. there are 502 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 31 complete
# Getting results for next coordinates.. there are 501 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 32 complete
# Getting results for next coordinates.. there are 500 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 33 complete
# Getting results for next coordinates.. there are 499 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 34 complete
# Getting results for next coordinates.. there are 498 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 35 complete
# Getting results for next coordinates.. there are 497 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 36 complete
# Getting results for next coordinates.. there are 496 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 37 complete
# Getting results for next coordinates.. there are 495 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 38 complete
# Getting results for next coordinates.. there are 494 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 39 complete
# Getting results for next coordinates.. there are 493 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 40 complete
# Getting results for next coordinates.. there are 492 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 41 complete
# Getting results for next coordinates.. there are 491 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 42 complete
# Getting results for next coordinates.. there are 490 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 43 complete
# Getting results for next coordinates.. there are 489 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 44 complete
# Getting results for next coordinates.. there are 488 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 45 complete
# Getting results for next coordinates.. there are 487 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 46 complete
# Getting results for next coordinates.. there are 486 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 47 complete
# Getting results for next coordinates.. there are 485 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 48 complete
# Getting results for next coordinates.. there are 484 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 49 complete
# Getting results for next coordinates.. there are 483 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 50 complete
# Getting results for next coordinates.. there are 482 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 51 complete
# Getting results for next coordinates.. there are 481 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 52 complete
# Getting results for next coordinates.. there are 480 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# -----------------------------------------
# Data retrieval for coordinates 53 complete
# Getting results for next coordinates.. there are 479 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# -----------------------------------------
# Data retrieval for coordinates 54 complete
# Getting results for next coordinates.. there are 478 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 55 complete
# Getting results for next coordinates.. there are 477 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# -----------------------------------------
# Data retrieval for coordinates 56 complete
# Getting results for next coordinates.. there are 476 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# Now processing query set 6 of max 20
# -----------------------------------------
# Data retrieval for coordinates 57 complete
# Getting results for next coordinates.. there are 475 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 58 complete
# Getting results for next coordinates.. there are 474 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 59 complete
# Getting results for next coordinates.. there are 473 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# -----------------------------------------
# Data retrieval for coordinates 60 complete
# Getting results for next coordinates.. there are 472 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# -----------------------------------------
# Data retrieval for coordinates 61 complete
# Getting results for next coordinates.. there are 471 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 62 complete
# Getting results for next coordinates.. there are 470 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 63 complete
# Getting results for next coordinates.. there are 469 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 64 complete
# Getting results for next coordinates.. there are 468 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 65 complete
# Getting results for next coordinates.. there are 467 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 66 complete
# Getting results for next coordinates.. there are 466 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 67 complete
# Getting results for next coordinates.. there are 465 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 68 complete
# Getting results for next coordinates.. there are 464 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 69 complete
# Getting results for next coordinates.. there are 463 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 70 complete
# Getting results for next coordinates.. there are 462 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 71 complete
# Getting results for next coordinates.. there are 461 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# -----------------------------------------
# Data retrieval for coordinates 72 complete
# Getting results for next coordinates.. there are 460 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# -----------------------------------------
# Data retrieval for coordinates 73 complete
# Getting results for next coordinates.. there are 459 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 74 complete
# Getting results for next coordinates.. there are 458 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# Now processing query set 6 of max 20
# Now processing query set 7 of max 20
# Now processing query set 8 of max 20
# Now processing query set 9 of max 20
# Now processing query set 10 of max 20
# Now processing query set 11 of max 20
# Now processing query set 12 of max 20
# Now processing query set 13 of max 20
# Now processing query set 14 of max 20
# Now processing query set 15 of max 20
# Now processing query set 16 of max 20
# Now processing query set 17 of max 20
# -----------------------------------------
# Data retrieval for coordinates 75 complete
# Getting results for next coordinates.. there are 457 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# Now processing query set 6 of max 20
# Now processing query set 7 of max 20
# Now processing query set 8 of max 20
# Now processing query set 9 of max 20
# Now processing query set 10 of max 20
# Now processing query set 11 of max 20
# Now processing query set 12 of max 20
# Now processing query set 13 of max 20
# Now processing query set 14 of max 20
# Now processing query set 15 of max 20
# Now processing query set 16 of max 20
# Now processing query set 17 of max 20
# Now processing query set 18 of max 20
# Now processing query set 19 of max 20
# Now processing query set 20 of max 20
# -----------------------------------------
# Data retrieval for coordinates 76 complete
# Getting results for next coordinates.. there are 456 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 77 complete
# Getting results for next coordinates.. there are 455 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 78 complete
# Getting results for next coordinates.. there are 454 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# -----------------------------------------
# Data retrieval for coordinates 79 complete
# Getting results for next coordinates.. there are 453 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# -----------------------------------------
# Data retrieval for coordinates 80 complete
# Getting results for next coordinates.. there are 452 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# -----------------------------------------
# Data retrieval for coordinates 81 complete
# Getting results for next coordinates.. there are 451 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 82 complete
# Getting results for next coordinates.. there are 450 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 83 complete
# Getting results for next coordinates.. there are 449 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 84 complete
# Getting results for next coordinates.. there are 448 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 85 complete
# Getting results for next coordinates.. there are 447 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 86 complete
# Getting results for next coordinates.. there are 446 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 87 complete
# Getting results for next coordinates.. there are 445 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 88 complete
# Getting results for next coordinates.. there are 444 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 89 complete
# Getting results for next coordinates.. there are 443 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 90 complete
# Getting results for next coordinates.. there are 442 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# -----------------------------------------
# Data retrieval for coordinates 91 complete
# Getting results for next coordinates.. there are 441 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# Now processing query set 6 of max 20
# -----------------------------------------
# Data retrieval for coordinates 92 complete
# Getting results for next coordinates.. there are 440 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 93 complete
# Getting results for next coordinates.. there are 439 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# Now processing query set 6 of max 20
# Now processing query set 7 of max 20
# Now processing query set 8 of max 20
# Now processing query set 9 of max 20
# Now processing query set 10 of max 20
# Now processing query set 11 of max 20
# Now processing query set 12 of max 20
# Now processing query set 13 of max 20
# Now processing query set 14 of max 20
# Now processing query set 15 of max 20
# Now processing query set 16 of max 20
# Now processing query set 17 of max 20
# Now processing query set 18 of max 20
# Now processing query set 19 of max 20
# Now processing query set 20 of max 20
# -----------------------------------------
# Data retrieval for coordinates 94 complete
# Getting results for next coordinates.. there are 438 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# Now processing query set 6 of max 20
# Now processing query set 7 of max 20
# Now processing query set 8 of max 20
# Now processing query set 9 of max 20
# Now processing query set 10 of max 20
# Now processing query set 11 of max 20
# Now processing query set 12 of max 20
# Now processing query set 13 of max 20
# Now processing query set 14 of max 20
# Now processing query set 15 of max 20
# Now processing query set 16 of max 20
# Now processing query set 17 of max 20
# Now processing query set 18 of max 20
# Now processing query set 19 of max 20
# Now processing query set 20 of max 20
# -----------------------------------------
# Data retrieval for coordinates 95 complete
# Getting results for next coordinates.. there are 437 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 96 complete
# Getting results for next coordinates.. there are 436 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 97 complete
# Getting results for next coordinates.. there are 435 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 98 complete
# Getting results for next coordinates.. there are 434 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# -----------------------------------------
# Data retrieval for coordinates 99 complete
# Getting results for next coordinates.. there are 433 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# Now processing query set 6 of max 20
# Now processing query set 7 of max 20
# Now processing query set 8 of max 20
# Now processing query set 9 of max 20
# Now processing query set 10 of max 20
# -----------------------------------------
# Data retrieval for coordinates 100 complete
# Getting results for next coordinates.. there are 432 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# Now processing query set 6 of max 20
# -----------------------------------------
# Data retrieval for coordinates 101 complete
# Getting results for next coordinates.. there are 431 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 102 complete
# Getting results for next coordinates.. there are 430 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# -----------------------------------------
# Data retrieval for coordinates 103 complete
# Getting results for next coordinates.. there are 429 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 104 complete
# Getting results for next coordinates.. there are 428 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 105 complete
# Getting results for next coordinates.. there are 427 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 106 complete
# Getting results for next coordinates.. there are 426 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 107 complete
# Getting results for next coordinates.. there are 425 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 108 complete
# Getting results for next coordinates.. there are 424 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 109 complete
# Getting results for next coordinates.. there are 423 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# -----------------------------------------
# Data retrieval for coordinates 110 complete
# Getting results for next coordinates.. there are 422 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# -----------------------------------------
# Data retrieval for coordinates 111 complete
# Getting results for next coordinates.. there are 421 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 112 complete
# Getting results for next coordinates.. there are 420 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# Now processing query set 6 of max 20
# Now processing query set 7 of max 20
# Now processing query set 8 of max 20
# Now processing query set 9 of max 20
# Now processing query set 10 of max 20
# Now processing query set 11 of max 20
# Now processing query set 12 of max 20
# Now processing query set 13 of max 20
# Now processing query set 14 of max 20
# Now processing query set 15 of max 20
# Now processing query set 16 of max 20
# Now processing query set 17 of max 20
# Now processing query set 18 of max 20
# -----------------------------------------
# Data retrieval for coordinates 113 complete
# Getting results for next coordinates.. there are 419 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# Now processing query set 6 of max 20
# Now processing query set 7 of max 20
# Now processing query set 8 of max 20
# Now processing query set 9 of max 20
# Now processing query set 10 of max 20
# Now processing query set 11 of max 20
# Now processing query set 12 of max 20
# Now processing query set 13 of max 20
# Now processing query set 14 of max 20
# Now processing query set 15 of max 20
# Now processing query set 16 of max 20
# Now processing query set 17 of max 20
# Now processing query set 18 of max 20
# Now processing query set 19 of max 20
# Now processing query set 20 of max 20
# -----------------------------------------
# Data retrieval for coordinates 114 complete
# Getting results for next coordinates.. there are 418 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 115 complete
# Getting results for next coordinates.. there are 417 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 116 complete
# Getting results for next coordinates.. there are 416 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 117 complete
# Getting results for next coordinates.. there are 415 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# -----------------------------------------
# Data retrieval for coordinates 118 complete
# Getting results for next coordinates.. there are 414 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# Now processing query set 6 of max 20
# Now processing query set 7 of max 20
# Now processing query set 8 of max 20
# Now processing query set 9 of max 20
# Now processing query set 10 of max 20
# Now processing query set 11 of max 20
# Now processing query set 12 of max 20
# -----------------------------------------
# Data retrieval for coordinates 119 complete
# Getting results for next coordinates.. there are 413 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# Now processing query set 6 of max 20
# Now processing query set 7 of max 20
# -----------------------------------------
# Data retrieval for coordinates 120 complete
# Getting results for next coordinates.. there are 412 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 121 complete
# Getting results for next coordinates.. there are 411 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# -----------------------------------------
# Data retrieval for coordinates 122 complete
# Getting results for next coordinates.. there are 410 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 123 complete
# Getting results for next coordinates.. there are 409 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 124 complete
# Getting results for next coordinates.. there are 408 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 125 complete
# Getting results for next coordinates.. there are 407 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 126 complete
# Getting results for next coordinates.. there are 406 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# -----------------------------------------
# Data retrieval for coordinates 127 complete
# Getting results for next coordinates.. there are 405 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# -----------------------------------------
# Data retrieval for coordinates 128 complete
# Getting results for next coordinates.. there are 404 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# -----------------------------------------
# Data retrieval for coordinates 129 complete
# Getting results for next coordinates.. there are 403 left
# -----------------------------------------
# Now processing query set 1 of max 20
# -----------------------------------------
# Data retrieval for coordinates 130 complete
# Getting results for next coordinates.. there are 402 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 131 complete
# Getting results for next coordinates.. there are 401 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# -----------------------------------------
# Data retrieval for coordinates 132 complete
# Getting results for next coordinates.. there are 400 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# Now processing query set 6 of max 20
# Now processing query set 7 of max 20
# Now processing query set 8 of max 20
# Now processing query set 9 of max 20
# Now processing query set 10 of max 20
# Now processing query set 11 of max 20
# Now processing query set 12 of max 20
# Now processing query set 13 of max 20
# Now processing query set 14 of max 20
# -----------------------------------------
# Data retrieval for coordinates 133 complete
# Getting results for next coordinates.. there are 399 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 134 complete
# Getting results for next coordinates.. there are 398 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 135 complete
# Getting results for next coordinates.. there are 397 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 136 complete
# Getting results for next coordinates.. there are 396 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# -----------------------------------------
# Data retrieval for coordinates 137 complete
# Getting results for next coordinates.. there are 395 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# Now processing query set 6 of max 20
# Now processing query set 7 of max 20
# Now processing query set 8 of max 20
# Now processing query set 9 of max 20
# Now processing query set 10 of max 20
# Now processing query set 11 of max 20
# -----------------------------------------
# Data retrieval for coordinates 138 complete
# Getting results for next coordinates.. there are 394 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# Now processing query set 6 of max 20
# Now processing query set 7 of max 20
# Now processing query set 8 of max 20
# -----------------------------------------
# Data retrieval for coordinates 139 complete
# Getting results for next coordinates.. there are 393 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 140 complete
# Getting results for next coordinates.. there are 392 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# -----------------------------------------
# Data retrieval for coordinates 141 complete
# Getting results for next coordinates.. there are 391 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# -----------------------------------------
# Data retrieval for coordinates 142 complete
# Getting results for next coordinates.. there are 390 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# Now processing query set 3 of max 20
# Now processing query set 4 of max 20
# Now processing query set 5 of max 20
# Now processing query set 6 of max 20
# -----------------------------------------
# Data retrieval for coordinates 143 complete
# Getting results for next coordinates.. there are 389 left
# -----------------------------------------
# Now processing query set 1 of max 20
# Now processing query set 2 of max 20
# -----------------------------------------
# Data retrieval for coordinates 144 complete
# Getting results for next coordinates.. there are 388 left
# -----------------------------------------
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Miniconda3\envs\PythonData\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\Miniconda3\envs\PythonData\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\Miniconda3\envs\PythonData\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Miniconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Miniconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Miniconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~\Miniconda3\envs\PythonData\lib\site-packages\urllib3\connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# ~\Miniconda3\envs\PythonData\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x000001ADFEE73860>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Miniconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Miniconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Miniconda3\envs\PythonData\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='api.yelp.com', port=443): Max retries exceeded with url: /v3/businesses/search?term=restaurants&sort_by=rating&latitude=38.364227&longitude=-122.091012&radius=8046&limit=50&offset=0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000001ADFEE73860>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-4-598899f30a64> in <module>
#      15
#      16     #  Call get_restaurants fn and append to total_count list
# ---> 17     totals_count.append(get_restaurants(lat_coords[index], lng_coords[index] , api_key))
#      18
#      19     # Print log history
#
# <ipython-input-3-4df36e6062c6> in get_restaurants(lat, lng, api_key)
#      13         params = {"term":"restaurants", "sort_by":"rating", "latitude":lat, "longitude":lng, "radius":8046,
#      14                   "limit":50, "offset":offset}
# ---> 15         req = requests.get(url, params=params, headers=headers)
#      16
#      17         # Breaks if error occurs with search
#
# ~\Miniconda3\envs\PythonData\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Miniconda3\envs\PythonData\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Miniconda3\envs\PythonData\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Miniconda3\envs\PythonData\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Miniconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='api.yelp.com', port=443): Max retries exceeded with url: /v3/businesses/search?term=restaurants&sort_by=rating&latitude=38.364227&longitude=-122.091012&radius=8046&limit=50&offset=0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000001ADFEE73860>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))

# %%
# Show coords_df with updated total # of restaurants
coords_df.head()
# Out:
#          Lat         Lng
# 0  38.871657 -123.109843
# 1  38.871657 -123.017222
# 2  38.871657 -122.924601
# 3  38.871657 -122.831980
# 4  38.871657 -122.739359

# %%
# Save restaurants counts to csv
coords_df.to_csv("Resources/total_count_coords_ratings.csv")

# %% [markdown]
# ### Create Dataframe
#
# - Read csv file
# - Clean data

# %%
# Read csv file
restaurants_df = pd.read_csv("Resources/restaurant_data_coords.csv", encoding = "ISO-8859-1", 
                            names=["search_ID", "Latitude_search", "Longitude_search", "Name", "Lat_Restaurant", "Lng_Restaurant", "Address", "Zip", 
                                   "Rating", "# of Reviews", "Price Level", "Category", "Yelp ID"])

# Replace NaN entries with blank string
restaurants_df = restaurants_df.fillna('')
restaurants_df.head()
# Out:
#                 search_ID  Latitude_search  Longitude_search  \
# 0  38.871657, -123.017222        38.871657       -123.017222
# 1  38.871657, -123.017222        38.871657       -123.017222
# 2  38.871657, -123.017222        38.871657       -123.017222
# 3  38.871657, -123.017222        38.871657       -123.017222
# 4  38.871657, -123.017222        38.871657       -123.017222
#
#                              Name  Lat_Restaurant  Lng_Restaurant  \
# 0                    Trading Post       38.805104     -123.016866
# 1     Hamburger Ranch & Bar-B-Que       38.817818     -123.023628
# 2  Railroad Station Bar and Grill       38.803078     -123.015378
# 3                    Zini's Diner       38.791995     -123.016825
# 4          Cloverdale Ale Company       38.805637     -123.015944
#
#                  Address    Zip  Rating  # of Reviews Price Level  \
# 0  102 S Cloverdale Blvd  95425     4.0           128          $$
# 1    31195 N Redwood Hwy  95425     4.0           381          $$
# 2  236 S Cloverdale Blvd  95425     4.0           223          $$
# 3  796 S Cloverdale Blvd  95425     4.0           108          $$
# 4           131 E 1st St  95425     4.0            21          $$
#
#                  Category                 Yelp ID
# 0                Bakeries  6o26tulocbwnkZx89EVHkA
# 1                Barbeque  0Dj4fW3J3DJzrI51PLadRA
# 2          American (New)  slg-wyyA57sZSMWmNshl-Q
# 3  American (Traditional)  qqpHX6ksqim3Sgm94zkTLA
# 4                    Pubs  wAbWk-do6kAUt3V9z8f9Wg

# %%
### Clean data, how to treat missing address, zip, price level, food trucks/mobile, low review counts
### Groupby on df
