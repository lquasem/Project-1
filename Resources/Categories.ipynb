# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# %%
Categories_df = pd.read_csv("restaurant_data_coords3.csv")

Categories_df
# Out:
#        Unnamed: 0                               Query ID      Query Lat  \
# 0             0.0          38.842665000000004-123.017222      38.842665
# 1             1.0          38.842665000000004-123.017222      38.842665
# 2             2.0          38.842665000000004-123.017222      38.842665
# 3             3.0          38.842665000000004-123.017222      38.842665
# 4             4.0          38.842665000000004-123.017222      38.842665
# 5             5.0          38.842665000000004-123.017222      38.842665
# 6             6.0          38.842665000000004-123.017222      38.842665
# 7             7.0          38.842665000000004-123.017222      38.842665
# 8             8.0          38.842665000000004-123.017222      38.842665
# 9             9.0          38.842665000000004-123.017222      38.842665
# 10           10.0          38.842665000000004-123.017222      38.842665
# 11           11.0          38.842665000000004-122.739332      38.842665
# ...

# %%
Categories= Categories_df["Category"].unique()

Categories
print(Categories_df[['Category']])
# Out:
#                                                 Category
# 0                 ['American (New)', 'Southern', 'Pubs']
# 1                                ['Barbeque', 'Burgers']
# 2                 ['Bakeries', 'American (New)', 'Bars']
# 3         ['Pubs', 'Beer Bar', 'American (Traditional)']
# 4                  ['Italian', 'Steakhouses', 'Seafood']
# 5                                        ['Restaurants']
# 6                       ['Pizza', 'Salad', 'Sandwiches']
# 7                                              ['Delis']
# 8                                            ['Mexican']
# 9      ['Burgers', 'Ice Cream & Frozen Yogurt', 'Sand...
# 10                              ['Food Trucks', 'Wraps']
# 11                 ['American (Traditional)', 'Burgers']
# 12                                             ['Pizza']
# 13                ['Coffee & Tea', 'Breakfast & Brunch']
# 14                              ['Food Trucks', 'Wraps']
# ...

# %%
Categories_df[Categories_df['Category'] !='Used Bookstore']
Categories_df[Categories_df['Category'] !='Pool Halls']
Categories_df[Categories_df['Category'] !='Health Markets']
Categories_df[Categories_df['Category'] !='Shared Office Spaces']
Categories_df[Categories_df['Category'] !='Couriers & Delivery Services']
Categories_df[Categories_df['Category'] !='Community Service/Non-Profit']
Categories_df[Categories_df['Category'] !='Bike Repair/Maintenance']
Categories_df[Categories_df['Category'] !="Contractors"]
Categories_df[Categories_df['Category'] !='Convenience Stores']
Categories_df[Categories_df['Category'] !='Department Stores']
Categories_df[Categories_df['Category'] !='Cooking Schools']
Categories_df[Categories_df['Category'] !="Caterers"]
Categories_df[Categories_df['Category'] !='Bowling']
Categories_df[Categories_df['Category'] !='Bookstores']
Categories_df[Categories_df['Category'] !='Food Trucks']
Categories_df[Categories_df['Category'] !='Street Vendors']
Categories_df[Categories_df['Category'] !='Grocery']
Categories_df[Categories_df['Category'] !='Shaved Ice']
Categories_df[Categories_df['Category'] !='Golf']
Categories_df[Categories_df['Category'] !='Mini Golf']
Categories_df[Categories_df['Category'] !='Laundromat']
Categories_df[Categories_df['Category'] !='Kids Activities']
# Out:
#        Unnamed: 0                               Query ID      Query Lat  \
# 0             0.0          38.842665000000004-123.017222      38.842665
# 1             1.0          38.842665000000004-123.017222      38.842665
# 2             2.0          38.842665000000004-123.017222      38.842665
# 3             3.0          38.842665000000004-123.017222      38.842665
# 4             4.0          38.842665000000004-123.017222      38.842665
# 5             5.0          38.842665000000004-123.017222      38.842665
# 6             6.0          38.842665000000004-123.017222      38.842665
# 7             7.0          38.842665000000004-123.017222      38.842665
# 8             8.0          38.842665000000004-123.017222      38.842665
# 9             9.0          38.842665000000004-123.017222      38.842665
# 10           10.0          38.842665000000004-123.017222      38.842665
# 11           11.0          38.842665000000004-122.739332      38.842665
# ...

# %%
old_df = pd.read_csv("merge_zip.csv")



cat_df= old_df["Category"].unique()

cat_df
# Out:
# array(['American (New)', 'Bakeries', 'Barbeque', 'Pubs', 'Italian',
#        'Restaurants', 'Mexican', 'Pizza', 'Delis', 'Burgers',
#        'Food Trucks', 'Desserts', 'Thai', 'Chinese',
#        'American (Traditional)', 'Grocery', 'Fast Food', 'Sandwiches',
#        'Gas Stations', 'Breweries', 'Caterers', 'Breakfast & Brunch',
#        'Hot Dogs', 'Steakhouses', 'Buffets', 'Sports Bars',
#        'Asian Fusion', 'Tex-Mex', 'Chicken Shop', 'Food Stands', 'Bars',
#        'Cafes', 'Tacos', 'Irish Pub', 'Afghan', 'Sushi Bars', 'Hawaiian',
#        'Indian', 'Kebab', 'Japanese', 'Coffee & Tea', 'Chicken Wings',
#        'Cheesesteaks', 'Diners', 'Salad', 'Mediterranean', 'Gluten-Free',
#        'Seafood', 'Soup', 'Patisserie/Cake Shop', 'Korean', 'Festivals',
#        'Soul Food', 'Fruits & Veggies', 'Hotels', 'Spanish',
#        'Latin American', 'Tapas/Small Plates', 'Meat Shops', 'Ramen',
#        'Cajun/Creole', 'Juice Bars & Smoothies', 'French', 'Cheese Shops',
# ...
